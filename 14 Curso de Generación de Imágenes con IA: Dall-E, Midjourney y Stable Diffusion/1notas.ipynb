# %% [markdown]
# # como instalar automatic 1111
#
# https://platzi.com/clases/6042-generacion-imagenes-ai/58983-instalacion-de-automatic-1111/
#
#
# ```
# Puedes agregar la opción --skip-torch-cuda-test al final del comando ./webui.sh de la siguiente manera:
#
# bash
#
# ./webui.sh --skip-torch-cuda-test
#
# Esto debería evitar que se ejecute el test de CUDA de PyTorch y permitir que el script se ejecute sin errores.
#
# ```
#
#
# para el archivo faltante
#
# ```
# No existe el archivo 768-v-ema.yaml en la ruta indicada:
# https://github.com/Stability-AI/stablediffusion/tree/main/configs/stable-diffusion
# Por favor indicar el enlace correcto. Gracias
# alarcon7a
#
# alarcon7a
#
# Profe Platzihace 2 meses
#
# tiene otro nombre porque lo usa toda la version 2,
#
# pero es este https://github.com/Stability-AI/stablediffusion/blob/main/configs/stable-diffusion/v2-inference.yaml
#
# ```

# %% [markdown]
# # usar stable difution en una interface como dalle ,
# https://beta.dreamstudio.ai/generate

# %% [markdown]
# #

# %% [markdown]
# # usar  dalle 2 como API con python
# https://platform.openai.com/docs/guides/images/introduction
#
# para usarla en note book hay que tener key y se genera en
#
# https://platform.openai.com/account/api-keys
#
#
# # PROMPT BOOK FOR DATA LOVER
#
# https://docs.google.com/presentation/d/1V8d6TIlKqB1j5xPFH7cCmgKOV_fMs4Cb4dwgjD5GIsg/edit#slide=id.g14c8a0b6339_2_136
#
# # prompt hero
# https://prompthero.com/
# # IMAGENES GENERADAS
# https://generrated.com/
#
#
# # estilos separados por artistas
