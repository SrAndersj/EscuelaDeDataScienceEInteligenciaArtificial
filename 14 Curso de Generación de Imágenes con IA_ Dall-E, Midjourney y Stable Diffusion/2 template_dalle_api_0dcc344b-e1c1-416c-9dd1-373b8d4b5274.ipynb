# %% [markdown]
# # Usando la API de DALL-E con Python

# %% [markdown]
# ## Instalación de librería de OpenAI

# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 KB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 10.2 MB/s eta 0:00:00
# ...

# %%
import os
import openai

openai.api_key ="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"
#openai.Model.list()

# %% [markdown]
# ## Consumir API

# %%
response = openai.Image.create(
  prompt="a white siamese cat",
  n=1,
  size="1024x1024"
)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-12-793c3f3d3d8c> in <cell line: 1>()
# ----> 1 response = openai.Image.create(
#       2   prompt="a white siamese cat",
#       3   n=1,
#       4   size="1024x1024"
#       5 )
#
# /usr/local/lib/python3.9/dist-packages/openai/api_resources/image.py in create(cls, api_key, api_base, api_type, api_version, organization, **params)
#      34         _, api_version = cls._get_api_type_and_version(api_type, api_version)
#      35
# ---> 36         response, _, api_key = requestor.request(
#      37             "post", cls._get_url("generations"), params
#      38         )
#
# /usr/local/lib/python3.9/dist-packages/openai/api_requestor.py in request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     224             request_timeout=request_timeout,
#     225         )
# ...

# %%
response['data']

# %%
from PIL import Image
import requests 
from io import BytesIO

# %% [markdown]
# ## Uso del API para variations

# %% [markdown]
# ## Imágenes en memoria
