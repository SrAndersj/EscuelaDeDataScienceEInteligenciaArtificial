# %% [markdown]
# https://wbd.ms/share/v2/aHR0cHM6Ly93aGl0ZWJvYXJkLm1pY3Jvc29mdC5jb20vYXBpL3YxLjAvd2hpdGVib2FyZHMvcmVkZWVtLzRlZmVmMGZjY2I4YzRiYTU4NGZmNWNjMjY1M2NhNGUxX0JCQTcxNzYyLTEyRTAtNDJFMS1CMzI0LTVCMTMxRjQyNEUzRF9jZmY4MGEyNS0xN2YwLTQ1YWYtODkxOC1jMTk2ZDdhODM0NzY=

# %%
import numpy as np

# %% [markdown]
# #pedirle a numpy que los resultados muy cercanos a 0
# #me los muestre como 0

# %%
np.set_printoptions(suppress=True)

# %%
A = np.array([[3,1],[2,1]])
A
# Out:
# array([[3, 1],
#        [2, 1]])

# %%
b = np.array([[1],[1]])
b
# Out:
# array([[1],
#        [1]])

# %%
inversa_A = np.linalg.inv(A)

inversa_A
# Out:
# array([[ 1., -1.],
#        [-2.,  3.]])

# %%
x=inversa_A.dot(b)
x
# Out:
# array([[0.],
#        [1.]])

# %%
A.dot(x)
# Out:
# array([[1.],
#        [1.]])

# %% [markdown]
# solucion 2

# %%
sol_2 = inversa_A.dot(np.array([[3],[7]]))

sol_2
# Out:
# array([[-4.],
#        [15.]])

# %%
A.dot(sol_2)
# Out:
# array([[3.],
#        [7.]])
