# %% [markdown]
# [Pizarra Microsoft Whitheboard](https://wbd.ms/share/v2/aHR0cHM6Ly93aGl0ZWJvYXJkLm1pY3Jvc29mdC5jb20vYXBpL3YxLjAvd2hpdGVib2FyZHMvcmVkZWVtLzhhZDdmOTY4MzRlOTRhY2FiZGE4NjFmZDE3MjU5YjRjX0JCQTcxNzYyLTEyRTAtNDJFMS1CMzI0LTVCMTMxRjQyNEUzRF9iMDA3OTU5OC1lZThlLTQ3MDgtOTYxYy1mY2VmNzM5ZWRkMDU=)

# %%
import numpy as np

# %%
vector = np.array([1,2,0,5,6,0])

np.linalg.norm(vector, ord=0)
# Out:
# 4.0

# %%
np.linalg.norm(vector, ord=1)
# Out:
# 14.0

# %%
np.linalg.norm(vector, ord=2)
# Out:
# 8.12403840463596

# %%
np.linalg.norm(vector, ord=3)
# Out:
# 7.047298732064891

# %% [markdown]
# # L0
# ## supongamos que estamos representando en un vector la cantidad de personas que hicieron una compra
#
# mejor dicho
# la cantidad de compras que realizo cada usuario
#
#
# si quisieramos saber cuantos usuarios hicieron compras entonces calculariamos la norma cero a este vector

# %% [markdown]
# # L1
#
# L1 nos devuelve la suma de los calores absolutos

# %%
vector = np.array([1,-1,1,-1,1])


np.linalg.norm(vector, ord=1)
# Out:
# 5.0

# %% [markdown]
# # L2

# %%
vector = np.array([1,1])

print(np.linalg.norm(vector)) # numpy por defecto devuelve la norma 2


print(np.linalg.norm(vector,ord=2))
# Out:
# 1.4142135623730951
# 1.4142135623730951

# %% [markdown]
# # $(L2)^2$

# %%
vector = np.array([1,2,3,4,5,6])
vector
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
np.linalg.norm(vector)**2
# Out:
# 91.0

# %%
vector.T.dot(vector)
# Out:
# 91

# %% [markdown]
# # $L\infty$

# %%
vector = np.array([1,2,3,-100])

np.linalg.norm(vector, ord=np.inf)
# Out:
# 100.0
