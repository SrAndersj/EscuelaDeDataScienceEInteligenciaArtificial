# %%
import numpy as np

# %%
escalar = 5.679
vector = np.array([3,4,5,6])
matriz = np.array([[1,2],[3,4],[5,6]])
tensor = np.array([
    [[1,2,3,30],[4,5,6,31],[7,8,9,32]],
    [[11,12,13,33],[14,15,16,34],[17,18,19,35]],
    [[21,22,23,36],[24,25,26,37],[27,28,29,38]],
])

# %%
print(vector)
# Out:
# [3 4 5 6]

# %%
vector_t=vector.T

print(vector_t)
# Out:
# [3 4 5 6]

# %%
print(matriz)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
matriz_t=matriz.T

print(matriz_t)
# Out:
# [[1 3 5]
#  [2 4 6]]

# %%
matriz.shape
# Out:
# (3, 2)

# %%
matriz_t.shape
# Out:
# (2, 3)

# %%
print(tensor)
# Out:
# [[[ 1  2  3 30]
#   [ 4  5  6 31]
#   [ 7  8  9 32]]
#
#  [[11 12 13 33]
#   [14 15 16 34]
#   [17 18 19 35]]
#
#  [[21 22 23 36]
#   [24 25 26 37]
#   [27 28 29 38]]]

# %%
tensor_t=tensor.T

print(tensor_t)
# Out:
# [[[ 1 11 21]
#   [ 4 14 24]
#   [ 7 17 27]]
#
#  [[ 2 12 22]
#   [ 5 15 25]
#   [ 8 18 28]]
#
#  [[ 3 13 23]
#   [ 6 16 26]
#   [ 9 19 29]]
#
#  [[30 33 36]
#   [31 34 37]
#   [32 35 38]]]

# %% [markdown]
# transpuesta de trasnpuesta es la original

# %%
matriz_t_t = matriz_t.T
print(matriz_t_t)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %% [markdown]
# # sumas

# %%
A=matriz
B=matriz_t

# %%
C=A+B  # no tienen las mismas dimensiones
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-72e89753e2c4> in <cell line: 1>()
# ----> 1 C=A+B
#
# ValueError: operands could not be broadcast together with shapes (3,2) (2,3)

# %%
A = np.array([[1,2],[3,4],[5,6]])
B = np.array([[6,5],[4,3],[2,1]])
C = A+B
print(A )
print(' ')
print(B)
print(' ')
print(C)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
#
# [[6 5]
#  [4 3]
#  [2 1]]
#
# [[7 7]
#  [7 7]
#  [7 7]]

# %%
matriz
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
escalar
# Out:
# 5.679

# %%
D=matriz +escalar
D
# Out:
# array([[ 6.679,  7.679],
#        [ 8.679,  9.679],
#        [10.679, 11.679]])
