# %%
import numpy as np

# %%
escalar = 5.679
vector = np.array([3,4,5])
matriz = np.array([[1,2],[3,4],[5,6]])

# %%
vector
# Out:
# array([3, 4, 5])

# %%
A = vector + matriz # no coinciden las dimensiones
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-57bf6f3bc9e4> in <cell line: 1>()
# ----> 1 A = vector + matriz
#
# ValueError: operands could not be broadcast together with shapes (3,) (3,2)

# %% [markdown]
# # brodcasting es extender la dimension de menor tamaño

# %%
C = matriz + 42
print(C)
# Out:
# [[43 44]
#  [45 46]
#  [47 48]]

# %%
np.array([[42],[42],[42]])
# Out:
# array([[42],
#        [42],
#        [42]])

# %%
D = matriz + np.array([[42],[42],[42]])
print(D)
# Out:
# [[43 44]
#  [45 46]
#  [47 48]]
