# %% [markdown]
# # pizarra online microsoft Whiteboard
# https://wbd.ms/share/v2/aHR0cHM6Ly93aGl0ZWJvYXJkLm1pY3Jvc29mdC5jb20vYXBpL3YxLjAvd2hpdGVib2FyZHMvcmVkZWVtL2E5YWJhZTkxYjhhZjRmY2RhM2MxZTVlODBlMTU0N2E5X0JCQTcxNzYyLTEyRTAtNDJFMS1CMzI0LTVCMTMxRjQyNEUzRF9hMjJhMjlkMS1lYjI4LTRkNTUtYmIxZC1mMThlODc4MjE3MmM=
#
# email jhonnatan.castano@

# %%
import numpy as np

# %%
escalar = 5.679
vector = np.array([2,3])
matriz = np.array([[1,2],[3,4],[5,6]])

# %%
vector
# Out:
# array([2, 3])

# %%
matriz
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
A = matriz * vector

# %%
A
# Out:
# array([[ 2,  6],
#        [ 6, 12],
#        [10, 18]])

# %%
B=matriz.dot(vector)

# %%
B
# Out:
# array([ 8, 18, 28])

# %%
B=matriz.dot(vector)
C=np.dot(matriz,vector)

# %%
C
# Out:
# array([ 8, 18, 28])
