# %% [markdown]
# pizarra
#
# https://wbd.ms/share/v2/aHR0cHM6Ly93aGl0ZWJvYXJkLm1pY3Jvc29mdC5jb20vYXBpL3YxLjAvd2hpdGVib2FyZHMvcmVkZWVtLzg0NTgzZGY4ZTY2NzQ2OTdiZDNmNDQ5MTJjZDJmNjA2X0JCQTcxNzYyLTEyRTAtNDJFMS1CMzI0LTVCMTMxRjQyNEUzRF81ZDVmZjBmOC04ZDY5LTQ4NjctOTViYy03MDk5NGUwOTE0ZTU=

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-5,5)

# %%
y_1 = 3*x + 5
y_2 = 2*x + 3

# %%
plt.figure()

plt.plot(x, y_1)
plt.plot(x, y_2)

plt.xlim(-5,5)
plt.ylim(-5,5)

plt.axvline(x=0, color='green')
plt.axhline(y=0, color='grey')

# %% [markdown]
# forma matricial de las ecuaciones

# %%
A=np.array([[-3,1],[-2,1]])
A
# Out:
# array([[-3,  1],
#        [-2,  1]])

# %%
b=np.array([[5],[3]])
b
# Out:
# array([[5],
#        [3]])

# %% [markdown]
# solucion

# %%
sol_1=np.array([-2,-1])

# %%
A.dot(sol_1)
# Out:
# array([5, 3])
