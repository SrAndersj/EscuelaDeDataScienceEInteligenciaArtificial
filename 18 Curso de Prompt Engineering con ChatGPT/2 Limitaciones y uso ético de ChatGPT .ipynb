# %% [markdown]
# # Falta de compresion profunda
#  ## respuestas plausibles pero incorrectas
#  alucinaciones es que el esta convencido de una respuesta  pero es erronea
#
#
#  ## vulnerabilidad a  manipulacion
#
#  ## respuestas repetitivas , extenso y repetitivo
#  una palabra se repite mucho , overfit
#
# ## dificultad de mantener contexto
