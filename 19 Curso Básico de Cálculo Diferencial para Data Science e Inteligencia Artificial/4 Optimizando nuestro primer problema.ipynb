# %% [markdown]
# Freddy y cristian quieren construir oficinas con vista al mar
#
#
# podemos construir tres muros y la parte a la playa libre
#
# operaciones dice si pero salen caras
#
# solo podemos construir 50 metros de perimetro
#
#
# con esos 50 metros de perimetro y 3 paredes cual es la configuracion ideal de largo y de ancho para obtender la mayor cantidad de area
#
#
#
# [Pizarra Microsoft Whitheboard](https://wbd.ms/share/v2/aHR0cHM6Ly93aGl0ZWJvYXJkLm1pY3Jvc29mdC5jb20vYXBpL3YxLjAvd2hpdGVib2FyZHMvcmVkZWVtLzIzYjljZThhYjQ2YTRhMWNiYTUyNDQ0YjcyYjcxOTEwX0JCQTcxNzYyLTEyRTAtNDJFMS1CMzI0LTVCMTMxRjQyNEUzRF83MDk2NDJjYi0xZDk1LTQ0MzQtYTAzNC1hMTM2NTcxMmU0ZGQ=)
