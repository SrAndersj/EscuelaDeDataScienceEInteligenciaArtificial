# %% [markdown]
# # PIP
# Dentro de python tenemos muchos modulos escritos por otrar personas
# entonces un python tiene modulos default o se instalan con pip
#
# hay otros modulos populares son
# ## Requests
# ## BeautifulSoup4
# ## pandas
# ## Numpy
# ## Pytest
