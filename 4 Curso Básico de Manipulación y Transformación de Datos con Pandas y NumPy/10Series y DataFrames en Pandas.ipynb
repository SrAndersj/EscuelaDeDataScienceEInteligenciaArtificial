# %% [markdown]
# # Pandas series
#
# operaciones aritmeticas
# distintos tipos de datos
#
# # pandas dataframe
#
# Estructura principal
# arreglo de dos dimensiones
# busqueda por indice(columnas o filas)
#
# slicing
# operaciones aritmeticas
# distintos tipos de datos
# tamaño variable

# %%
import pandas as pd

# %%
psg_players =pd.Series(['Navas','Mbappe','Neymar','Messi'],
          index=[1,7,10,30]
          )
psg_players
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %% [markdown]
# # que pasa si no defino los indices

# %%
pd.Series(['Navas','Mbappe','Neymar','Messi'])
# Out:
# 0     Navas
# 1    Mbappe
# 2    Neymar
# 3     Messi
# dtype: object

# %% [markdown]
# # ahora crear dataframe por medio de un diccionario

# %%
dict = {1:'Navas',7:'Mbappe',10:'Neymar',30:'Messi'}
pd.Series(dict)
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
psg_players[1]
# Out:
# 'Navas'

# %%
psg_players[0:3]
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# dtype: object

# %% [markdown]
# # que pasa si necestio tener mas cosas , mas informacion pero en un dataframe
#
#
# como ahora tengo 3 dimensiones uso Dataframe que es matricial

# %%
dict={'Jugador':['Navas','Mbappe','Neymar','Messi'],
 'Altura':[183,170,170,165],
 'Goles':[2,200,200,200]
 
 
 }

# %%
pd.DataFrame(dict,index=[1,7,10,10])
# Out:
#    Jugador  Altura  Goles
# 1    Navas     183      2
# 7   Mbappe     170    200
# 10  Neymar     170    200
# 10   Messi     165    200

# %%
pd.DataFrame(dict)
# Out:
#   Jugador  Altura  Goles
# 0   Navas     183      2
# 1  Mbappe     170    200
# 2  Neymar     170    200
# 3   Messi     165    200

# %%
df_players=pd.DataFrame(dict)
df_players.columns
# Out:
# Index(['Jugador', 'Altura', 'Goles'], dtype='object')

# %%
df_players.index
# Out:
# RangeIndex(start=0, stop=4, step=1)
