# %%
import numpy as np

# %% [markdown]
# # shape dice la forma que tiene un arreglo

# %%
arr = np.random.randint(1,10,(3,2))
arr
# Out:
# array([[8, 3],
#        [1, 9],
#        [6, 9]])

# %%
arr.shape
# Out:
# (3, 2)

# %%
arr.reshape(1,6)
# Out:
# array([[8, 3, 1, 9, 6, 9]])

# %%
arr.reshape(2,3)
# Out:
# array([[8, 3, 1],
#        [9, 6, 9]])

# %%
np.reshape(arr,(1,6))
# Out:
# array([[8, 3, 1, 9, 6, 9]])

# %% [markdown]
# #ahora vamos a ver como esta ordenando

# %%
arr
# Out:
# array([[8, 3],
#        [1, 9],
#        [6, 9]])

# %%
# reordenar como lo hace en el lenguaje C
np.reshape(arr,(2,3),'C')
# Out:
# array([[8, 3, 1],
#        [9, 6, 9]])

# %%
# reordenar como lo hace en el lenguaje fortran
np.reshape(arr,(2,3),'F')
# Out:
# array([[8, 6, 9],
#        [1, 3, 9]])

# %%
# reordenar como lo hace la optimizacion de mi sistema , de mi laptop
np.reshape(arr,(2,3),'A')
# Out:
# array([[8, 3, 1],
#        [9, 6, 9]])
