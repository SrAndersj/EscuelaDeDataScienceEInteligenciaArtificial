# %%
import numpy as np

# %%
arr = np.random.randint(1,20,10)
arr
# Out:
# array([ 2, 10,  9, 17,  3,  8,  1,  5, 14,  2])

# %%
matriz=arr.reshape(2,5)
matriz
# Out:
# array([[ 2, 10,  9, 17,  3],
#        [ 8,  1,  5, 14,  2]])

# %% [markdown]
# # numero mas grande que tenga el array

# %%
arr.max()
# Out:
# 17

# %%
matriz.max()
# Out:
# 17

# %% [markdown]
# # que pasa si le digo que solo lo haga para el eje 1 osea fila
#
# # 0 es por columna

# %%
matriz.max(1)
# Out:
# array([17, 14])

# %%
matriz.max(0)
# Out:
# array([ 8, 10,  9, 17,  3])

# %% [markdown]
# # indice donde se encuentra el valor mas grande

# %%
arr.argmax()
# Out:
# 3

# %%
matriz.argmax(0) # aqui veo el indice del maximo por cada columna
# Out:
# array([1, 0, 0, 0, 0])

# %% [markdown]
# # minimos

# %%
arr.min()
# Out:
# 1

# %%
arr.argmin()
# Out:
# 6

# %% [markdown]
# # de un pico a otro pico
#
# de un pico mas bajo al mas alto cuantos datos hay

# %%
arr
# Out:
# array([ 2, 10,  9, 17,  3,  8,  1,  5, 14,  2])

# %%
arr.ptp()
# Out:
# 16

# %%
matriz.ptp(0)
# Out:
# array([6, 9, 4, 3, 1])

# %% [markdown]
# # percentil me va a especificar directamente el percentil que estoy trabajando

# %%
# percentil 50 o mediana
np.percentile(arr,50) # cual es el valor que se encuentra en la mitad
# Out:
# 6.5

# %% [markdown]
# # sort me ordena de menor a mayor los numeros que tengo en el arreglo

# %%
arr.sort()
arr
# Out:
# array([ 1,  2,  2,  3,  5,  8,  9, 10, 14, 17])

# %% [markdown]
# # la mediana

# %%
np.median(arr)
# Out:
# 6.5

# %%
np.median(matriz,1)
# Out:
# array([ 2., 10.])

# %% [markdown]
# Desviacion estandar

# %%
np.std(arr)
# Out:
# 5.18555686498567

# %% [markdown]
# # varianza

# %%
np.var(arr)
# Out:
# 26.890000000000004

# %% [markdown]
# # media

# %%
np.mean(arr)
# Out:
# 7.1

# %% [markdown]
# # concatenar
# unir array a con el b

# %%
a= np.array([[1,2],[3,4]])
b=np.array([5,6])

# %%
np.concatenate((a,b),axis=0) # da error porque b y a no tienen las mismas dimensiones
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-17464568486c> in <module>
# ----> 1 np.concatenate((a,b),axis=0)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 2 dimension(s) and the array at index 1 has 1 dimension(s)

# %%
a.ndim
# Out:
# 2

# %%
b.ndim
# Out:
# 1

# %% [markdown]
# # vamos a llevar a b a la misma dimension

# %%
b=np.expand_dims(b,axis=0)
b
# Out:
# array([[5, 6]])

# %%
b.ndim
# Out:
# 2

# %%
np.concatenate((a,b),axis=0)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %% [markdown]
# # para hacerlo columnar

# %%
b
# Out:
# array([[5, 6]])

# %%
# no funciona porque 5 y 6 no estan columnares se coluciona con reshape o transpueta
np.concatenate((a,b),axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-6e20b93aef3d> in <module>
# ----> 1 np.concatenate((a,b),axis=1)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 2 and the array at index 1 has size 1

# %%
# aqui usamos la transpuesta T
np.concatenate((a,b.T),axis=1)
# Out:
# array([[1, 2, 5],
#        [3, 4, 6]])

# %%
b.T
# Out:
# array([[5],
#        [6]])
