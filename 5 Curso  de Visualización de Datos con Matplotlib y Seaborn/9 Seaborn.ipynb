# %% [markdown]
# # construida en base de matploidlib
#
# # optimisado para trabajar con pandas
#
# velocidad , poco codigo , customizable

# %% [markdown]
# # tipos de graficas
#
# ## replot(relational)
#
# scatterplot
# lieplot
#
# ## displot(distributions)
#
# hisplot
# kdeplot
# ecdfplot
# rugplot
#
# ## catplot(categorical)
#
# stripplot
#
# swarmplot
#
# boxplot
#
# violinplot
#
# pointplot
#
# barplot
