# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

import scipy.stats as st


from scipy.stats import f_oneway

from scipy.stats import ttest_ind

# %% [markdown]
# #### De nuevo, usaremos la base de datos Iris

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
iris = pd.read_csv(url, names=names)
iris.head()
# Out:
#    sepal-length  sepal-width  petal-length  petal-width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## Tipos de pruebas:

# %% [markdown]
# ### a) Distribución t de Student

# %% [markdown]
# # $ SE =\frac{\sigma}{\sqrt{N}} $
#
# SE = standart error
#
# .std = standart desviation =$\sigma$

# %%
se_length =iris.std()['sepal-length']/np.sqrt(10)  

se_width = iris.std()['sepal-width']/np.sqrt(10)
# Out:
# <ipython-input-4-b23823d99f4e>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   se_length =iris.std()['sepal-length']/np.sqrt(10)
# <ipython-input-4-b23823d99f4e>:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   se_width = iris.std()['sepal-width']/np.sqrt(10)

# %% [markdown]
# # SED = standart error desviation
#
# # $SED =\sqrt{ \frac{\sigma_{1}^{2}}{N_1}+ \frac{\sigma_{1}^{2}}{N_2}} $

# %%
sed = np.sqrt((se_length**2)+se_width**2)

# %% [markdown]
# # $t = \frac{\bar{x_1}-\bar{x_2}}{SED}    $
#
#
# # $ t = \frac{x_1-x_2}{\frac{(s_{1})^2}{n_1}+\frac{(s_{2})^2}{n_2}}    $

# %%
t_stat =(iris.mean()['sepal-length']-iris.mean()['sepal-width'])/sed


t_stat
# Out:
# <ipython-input-6-b43ac6a5f398>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   t_stat =(iris.mean()['sepal-length']-iris.mean()['sepal-width'])/sed
# 9.436693738890318

# %% [markdown]
# # vamos a caluclar el valor de p

# %%
p =ttest_ind(iris['sepal-length'],iris['petal-width'])

p
# Out:
# Ttest_indResult(statistic=50.51520141387464, pvalue=3.7974378831185126e-148)

# %% [markdown]
# # si el valor absoluto del valor t es mayor que el valor crítico, entonces rechazamos la hipótesis nula ??
#
# ## respuesta
# Si el valor absoluto del valor t es mayor que el valor crítico, usted rechaza la hipótesis nula. Si el valor absoluto del valor t es menor que el valor crítico, usted no puede rechazar la hipótesis nula.
