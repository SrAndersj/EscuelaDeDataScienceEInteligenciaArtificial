# %%
#a = 'https://wbd.ms/share/v2/aHR0cHM6Ly93aGl0ZWJvYXJkLm1pY3Jvc29mdC5jb20vYXBpL3YxLjAvd2hpdGVib2FyZHMvcmVkZWVtLzhhZDdmOTY4MzRlOTRhY2FiZGE4NjFmZDE3MjU5YjRjX0JCQTcxNzYyLTEyRTAtNDJFMS1CMzI0LTVCMTMxRjQyNEUzRF9iMDA3OTU5OC1lZThlLTQ3MDgtOTYxYy1mY2VmNzM5ZWRkMDU='
a = input('Ingresa un valor para la variable a: ')

a_str = str(a)
result = '[Pizarra Microsoft Whitheboard](' + a_str + ')' 
print(result)
# Out:
# Ingresa un valor para la variable a: https://wbd.ms/share/v2/aHR0cHM6Ly93aGl0ZWJvYXJkLm1pY3Jvc29mdC5jb20vYXBpL3YxLjAvd2hpdGVib2FyZHMvcmVkZWVtLzJhZTQ1OTZjYjI5NjQwYzFiOGRlOTYxNDdhNDEwZGRiX0JCQTcxNzYyLTEyRTAtNDJFMS1CMzI0LTVCMTMxRjQyNEUzRF9jZDEyZjBiZS05Njc0LTQ1NWMtODI1Yi04NTE4NDA5NzM0NjQ=
# [Pizarra Microsoft Whitheboard](https://wbd.ms/share/v2/aHR0cHM6Ly93aGl0ZWJvYXJkLm1pY3Jvc29mdC5jb20vYXBpL3YxLjAvd2hpdGVib2FyZHMvcmVkZWVtLzJhZTQ1OTZjYjI5NjQwYzFiOGRlOTYxNDdhNDEwZGRiX0JCQTcxNzYyLTEyRTAtNDJFMS1CMzI0LTVCMTMxRjQyNEUzRF9jZDEyZjBiZS05Njc0LTQ1NWMtODI1Yi04NTE4NDA5NzM0NjQ=)
