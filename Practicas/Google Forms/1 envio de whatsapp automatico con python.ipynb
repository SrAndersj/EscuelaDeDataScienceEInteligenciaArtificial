# %% [markdown]
# ```
# sudo apt install python3-pip
#
#
# pip install pywhatkit
#
# ```

# %% [markdown]
# ```python
# import pywhatkit
#
# y = int(50)
# n="+573133297351"
# a="+573212581669"
# try:
#     #enviamos mensaje usando pywhatkit
#     #pywhatkit.sendwhatmsg("+573212581669","Este es un test de envio de data mediante python",22,20)
#
#     pywhatkit.sendwhatmsg(n,"asdfasdf test ",22,y,15,True,2)
#     pywhatkit.sendwhatmsg(a," este es un mensaje prehecho desde python ",22,y)
#
#
#
#     print("todo bien")
# except:
#     print("todo mal")
#
# ```

# %% [markdown]
# ```python
#
# import pywhatkit
#
# mylist=["+573133297351","+573212581669"]
#
# y = int(32)
#
#
#
# try:
#
#
#     for x in mylist:
#     #enviamos mensaje usando pywhatkit
#     #pywhatkit.sendwhatmsg("+573212581669","Este es un test de envio de data mediante python",22,20)
#
#         pywhatkit.sendwhatmsg(x,"test envio python ",10,y,15,True,2)
#
#         print("todo bien")
#
#         y=y+1
# except:
#     print("todo mal en el except ")
#
#
#
# ```

# %% [markdown]
# ```python
# import pywhatkit
#
# mylist=["+573133297351","+573212581669"]
#
# y = int(13)
#
#
#
# try:
#
#
#     for x in mylist:
#     #enviamos mensaje usando pywhatkit
#     #pywhatkit.sendwhatmsg("+573212581669","Este es un test de envio de data mediante python",22,20)
#
#         pywhatkit.sendwhatmsg(x,"este es un test ",14,y,10,True,2)
#
#         print("todo bien")
#
#         y=y+1
# except:
#     print("todo mal en el except ")
#
#
#
#
# ```

# %% [markdown]
# ```python
# import pywhatkit
#
# mylist=['+573012266359',
#  '+573213009009',
#  '+573153940957',
#  '+573228738485',
#  '+573157862669',
#  '+573173700213',
#  '+573214681987',
#  '+573174502576',
#  '+573174502576',
#  '+573194832941',
#  '+573118092177',
#  '+573165323839',
#  '+573106742047',
#  '+573157651042',
#  '+573213410531',
#  '+573164662250',
#  '+573164662250',
#  '+573243099353',
#  '+573174841329',
#  '+573114436987',
#  '+573123644736',
#  '+573175054345',
#  '+573013472740',
#  '+573214122539',
#  '+573045768537',
#  '+573142152190',
#  '+573132531300',
#  '+5731445489905',
#  '+573125287225',
#  '+573222374749',
#  '+57310588566']
#
# y = int(11)
#
#
#
# try:
#
#
#     for x in mylist:
#
#         pywhatkit.sendwhatmsg(x,"Muy Buenas Tardes ,Soy Andres. Muchas gracias por ingresar los datos en el formulario,espero estar enviando el documento entre el martes y el miercoles, pueden ver el documento en el siguient link https://docs.google.com/document/d/1aUHbZmfoaSxgsB6DAKGCOXq2MbzR8Pog/edit?usp=sharing&ouid=100170168595710561945&rtpof=true&sd=true , este mensaje lo envio mediante  un algoritmo que he creado en python(que sigue en desarrollo) por favor difundan la info en caso de que falle y no todos l@s inscritos se enteren.Muchas gracias,Juntos somos fuertes.Feliz tarde ",15,y,8,True,2)
#
#         print("todo bien")
#
#         y=y+1
# except:
#     print("todo mal en el except ")
#
#
#
#
#
# ```

# %% [markdown]
# ```python
#
# import pywhatkit
#
# mylist=['+573232312164',
#  '+573164509388',
#  '+573012266359',
#  '+573213009009',
#  '+573153940957',
#  '+573228738485',
#  '+573157862669',
#  '+573173700213',
#  '+573214681987',
#  '+573174502576',
#  '+573174502576',
#  '+573194832941',
#  '+573118092177',
#  '+573165323839',
#  '+573106742047',
#  '+573157651042',
#  '+573213410531',
#  '+573164662250',
#  '+573164662250',
#  '+573243099353',
#  '+573174841329',
#  '+573114436987',
#  '+573123644736',
#  '+573175054345',
#  '+573013472740',
#  '+573214122539',
#  '+573045768537',
#  '+573142152190',
#  '+573132531300',
#  '+5731445489905',
#  '+573125287225',
#  '+573222374749',
#  '+57310588566']
#
# y = int(17)
#
#
#
# try:
#
#
#     for x in mylist:
#
#         pywhatkit.sendwhatmsg(x,"Hola Soy Andres.La solicitud para la especializacion  ISO/IEC 17025 ya se realizo y tiene radicado 7-2023-068464 PQRS SENA, pueden ver el documento enviado  en:   https://docs.google.com/document/d/1aUHbZmfoaSxgsB6DAKGCOXq2MbzR8Pog/edit?usp=sharing&ouid=100170168595710561945&rtpof=true&sd=true , este  es un mensaje enviado automaticamente desde python y se encuentra en desarrollo por favor difundir por si no llega a todas las personas interesadas,Juntos somos fuertes.Feliz tarde ",12,y,8,True,2)
#
#         print("todo bien")
#
#         y=y+1
# except:
#     print("todo mal en el except ")
#
#
#
#
#
# ```
