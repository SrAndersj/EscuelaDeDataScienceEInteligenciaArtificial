# %%
import pandas as pd

import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
url='https://docs.google.com/spreadsheets/d/e/2PACX-1vQMVr8Cy2DN4e5XiTfdlulCQ0daWzEP6YNmccvzgUuWre5IgJ0hmLxi-LfMpqS7T-1msiWIIDR5fehX/pub?output=csv'

df=pd.read_csv(url)
df
# Out:
#         nombreSal  Cloruro De Sodio  Calcio  Fósforo  Magnesio  Azufre  Zinc  \
# 0      Supragan7               29.0      16        7       0.5       6  0.66
# 1  Ganazufre 3-14              37.9      12        3       0.3      14  0.56
#
#    Cobre  Yodo  Cobalto  Flúor  Humedad  Selenio   Cromo
# 0   0.15  0.01    0.007   0.07        5   0.0072     NaN
# 1   0.25  0.01    0.005   0.03        5   0.0050  0.0005

# %%
sns.barplot(df['nombreSal'],df['Cloruro De Sodio'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_T=df.transpose()
df_T
# Out:
#                            0               1
# nombreSal         Supragan7   Ganazufre 3-14
# Cloruro De Sodio        29.0            37.9
# Calcio                    16              12
# Fósforo                    7               3
# Magnesio                 0.5             0.3
# Azufre                     6              14
# Zinc                    0.66            0.56
# Cobre                   0.15            0.25
# Yodo                    0.01            0.01
# Cobalto                0.007           0.005
# Flúor                   0.07            0.03
# Humedad                    5               5
# Selenio               0.0072           0.005
# Cromo                    NaN          0.0005

# %%
#set column names equal to values in row index position 0
df_T.columns = df_T.iloc[0]

#remove first row from DataFrame
df_T = df_T[1:]

#view updated DataFrame
df_T
# Out:
# nombreSal        Supragan7  Ganazufre 3-14
# Cloruro De Sodio       29.0           37.9
# Calcio                   16             12
# Fósforo                   7              3
# Magnesio                0.5            0.3
# Azufre                    6             14
# Zinc                   0.66           0.56
# Cobre                  0.15           0.25
# Yodo                   0.01           0.01
# Cobalto               0.007          0.005
# Flúor                  0.07           0.03
# Humedad                   5              5
# Selenio              0.0072          0.005
# Cromo                   NaN         0.0005

# %%
df_T_resetIndex=df.T.reset_index()
df_T_resetIndex
# Out:
#                index           0               1
# 0          nombreSal  Supragan7   Ganazufre 3-14
# 1   Cloruro De Sodio        29.0            37.9
# 2             Calcio          16              12
# 3            Fósforo           7               3
# 4           Magnesio         0.5             0.3
# 5             Azufre           6              14
# 6               Zinc        0.66            0.56
# 7              Cobre        0.15            0.25
# 8               Yodo        0.01            0.01
# 9            Cobalto       0.007           0.005
# 10             Flúor        0.07            0.03
# 11           Humedad           5               5
# 12           Selenio      0.0072           0.005
# 13             Cromo         NaN          0.0005

# %%
#set column names equal to values in row index position 0
df_T_resetIndex.columns = df_T_resetIndex.iloc[0]

#remove first row from DataFrame
df_T_resetIndex = df_T_resetIndex[1:]

#view updated DataFrame

df=df_T_resetIndex
df
# Out:
# 0          nombreSal Supragan7  Ganazufre 3-14
# 1   Cloruro De Sodio       29.0           37.9
# 2             Calcio         16             12
# 3            Fósforo          7              3
# 4           Magnesio        0.5            0.3
# 5             Azufre          6             14
# 6               Zinc       0.66           0.56
# 7              Cobre       0.15           0.25
# 8               Yodo       0.01           0.01
# 9            Cobalto      0.007          0.005
# 10             Flúor       0.07           0.03
# 11           Humedad          5              5
# 12           Selenio     0.0072          0.005
# 13             Cromo        NaN         0.0005

# %%
df= df.reset_index(drop=True)
df
# Out:
# 0          nombreSal Supragan7  Ganazufre 3-14
# 0   Cloruro De Sodio       29.0           37.9
# 1             Calcio         16             12
# 2            Fósforo          7              3
# 3           Magnesio        0.5            0.3
# 4             Azufre          6             14
# 5               Zinc       0.66           0.56
# 6              Cobre       0.15           0.25
# 7               Yodo       0.01           0.01
# 8            Cobalto      0.007          0.005
# 9              Flúor       0.07           0.03
# 10           Humedad          5              5
# 11           Selenio     0.0072          0.005
# 12             Cromo        NaN         0.0005

# %% [markdown]
# # practica

# %%
#create DataFrame
df = pd.DataFrame({'Bad Name 1': ['team', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'],
                   'Bad Name 2': ['points', 18, 22, 19, 14, 14, 11, 20, 28],
                   'Bad Name 3': ['assists', 5, 7, 7, 9, 12, 9, 9, 4],
                   'Bad Name 4': ['rebounds', 11, 8, 10, 6, 6, 5, 9, 12]})

#view DataFrame
df
# Out:
#   Bad Name 1 Bad Name 2 Bad Name 3 Bad Name 4
# 0       team     points    assists   rebounds
# 1          A         18          5         11
# 2          B         22          7          8
# 3          C         19          7         10
# 4          D         14          9          6
# 5          E         14         12          6
# 6          F         11          9          5
# 7          G         20          9          9
# 8          H         28          4         12

# %%
#set column names equal to values in row index position 0
df.columns = df.iloc[0]

#remove first row from DataFrame
df = df[1:]

#view updated DataFrame
df
# Out:
# 0 team points assists rebounds
# 1    A     18       5       11
# 2    B     22       7        8
# 3    C     19       7       10
# 4    D     14       9        6
# 5    E     14      12        6
# 6    F     11       9        5
# 7    G     20       9        9
# 8    H     28       4       12

# %%
df.iloc[0]
# Out:
# 0
# team         A
# points      18
# assists      5
# rebounds    11
# Name: 1, dtype: object

# %%
df = df[1:]
df
# Out:
# 0 team points assists rebounds
# 2    B     22       7        8
# 3    C     19       7       10
# 4    D     14       9        6
# 5    E     14      12        6
# 6    F     11       9        5
# 7    G     20       9        9
# 8    H     28       4       12

# %%
import pandas as pd

dataframe = pd.DataFrame({'A': {0: 6, 1: 20, 2: 80,3: 78,4: 95}, 
                          'B': {0: 60, 1: 50, 2: 7,3: 67,4: 54}})

dataframe1 = dataframe.transpose()
print(dataframe)
# Out:
#     A   B
# 0   6  60
# 1  20  50
# 2  80   7
# 3  78  67
# 4  95  54

# %%
print(dataframe1)
# Out:
#     0   1   2   3   4
# A   6  20  80  78  95
# B  60  50   7  67  54

# %%
df_T['index']=np.arange(len(df_T))
df_T
# Out:
# <ipython-input-126-2e638d007167>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_T['index']=np.arange(len(df_T))
# nombreSal        Supragan7  Ganazufre 3-14  index
# Cloruro De Sodio       29.0           37.9      0
# Calcio                   16             12      1
# Fósforo                   7              3      2
# Magnesio                0.5            0.3      3
# Azufre                    6             14      4
# Zinc                   0.66           0.56      5
# Cobre                  0.15           0.25      6
# Yodo                   0.01           0.01      7
# Cobalto               0.007          0.005      8
# Flúor                  0.07           0.03      9
# Humedad                   5              5     10
# ...
