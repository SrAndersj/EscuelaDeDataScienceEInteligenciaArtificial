# %%
import pandas as pd

import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
url='https://docs.google.com/spreadsheets/d/e/2PACX-1vRx_CVnWnkHk8LDKLmB4llSA2WF917czueM4OdfFPMx1RqgYV3YICTeK5eXn5jeKh5ym-H3lYphe-19/pub?output=csv'
df=pd.read_csv(url)
df
# Out:
#        Formula                        Nombre  W or MW          color
# 0           Ca                       CALCIUM   40.078  silvery-white
# 1        CaCO3             CALCIUM CARBONATE  100.090            NaN
# 2         CaC2               CALCIUM CARBIDE   64.100            NaN
# 3        CaCl2              CALCIUM CHLORIDE      NaN            NaN
# 4        CaCN2             CALCIUM CYANAMIDE      NaN            NaN
# 5         CaF2              CALCIUM FLUORIDE   78.075            NaN
# 6         CaH2               CALCIUM HYDRIDE      NaN            NaN
# 7      Ca(OH)2             CALCIUM HYDROXIDE      NaN            NaN
# 8     Ca(OCl)2          CALCIUM HYPOCHLORITE      NaN            NaN
# 9     Ca(NO3)2               CALCIUM NITRATE      NaN            NaN
# 10         CaO                 CALCIUM OXIDE      NaN            NaN
# 11      CaHPO4    CALCIUM PHOSPHATE, DIBASIC      NaN            NaN
# 12  Ca(H2PO4)2  CALCIUM PHOSPHATE, MONOBASIC      NaN            NaN
# ...

# %%
df['Formula']
# Out:
# 0             Ca
# 1          CaCO3
# 2           CaC2
# 3          CaCl2
# 4          CaCN2
# 5           CaF2
# 6           CaH2
# 7        Ca(OH)2
# 8       Ca(OCl)2
# 9       Ca(NO3)2
# 10           CaO
# 11        CaHPO4
# 12    Ca(H2PO4)2
# 13     Ca3(PO4)3
# 14         CaSO4
# 15           CaS
# Name: Formula, dtype: object

# %%
df['Formula'].replace('CaCO3','\ch{CaCO3}' )
# Out:
# 0             Ca
# 1     \ch{CaCO3}
# 2           CaC2
# 3          CaCl2
# 4          CaCN2
# 5           CaF2
# 6           CaH2
# 7        Ca(OH)2
# 8       Ca(OCl)2
# 9       Ca(NO3)2
# 10           CaO
# 11        CaHPO4
# 12    Ca(H2PO4)2
# 13     Ca3(PO4)3
# 14         CaSO4
# 15           CaS
# Name: Formula, dtype: object

# %%
import pandas as pd
technologies = ({
     'Courses':["Spark","PySpark","Hadoop","Python","pandas"],
     'Fee' :[20000,25000,26000,22000,24000],
     'Duration':['30days','40days','35days','40days','60days'],
     'Discount':[1000,1500,2500,2100,2000]
               })
df = pd.DataFrame(technologies)
df
# Out:
#    Courses    Fee Duration  Discount
# 0    Spark  20000   30days      1000
# 1  PySpark  25000   40days      1500
# 2   Hadoop  26000   35days      2500
# 3   Python  22000   40days      2100
# 4   pandas  24000   60days      2000

# %%
# Using + operator to combine two columns
df["Period"] = df['Courses'].astype(str) +"-"+ df["Duration"]
print(df)
# Out:
#    Courses    Fee Duration  Discount          Period
# 0    Spark  20000   30days      1000    Spark-30days
# 1  PySpark  25000   40days      1500  PySpark-40days
# 2   Hadoop  26000   35days      2500   Hadoop-35days
# 3   Python  22000   40days      2100   Python-40days
# 4   pandas  24000   60days      2000   pandas-60days

# %%
url='https://docs.google.com/spreadsheets/d/e/2PACX-1vRx_CVnWnkHk8LDKLmB4llSA2WF917czueM4OdfFPMx1RqgYV3YICTeK5eXn5jeKh5ym-H3lYphe-19/pub?output=csv'
df=pd.read_csv(url)
df
# Out:
#        Formula                        Nombre  W or MW          color
# 0           Ca                       CALCIUM   40.078  silvery-white
# 1        CaCO3             CALCIUM CARBONATE  100.090            NaN
# 2         CaC2               CALCIUM CARBIDE   64.100            NaN
# 3        CaCl2              CALCIUM CHLORIDE      NaN            NaN
# 4        CaCN2             CALCIUM CYANAMIDE      NaN            NaN
# 5         CaF2              CALCIUM FLUORIDE   78.075            NaN
# 6         CaH2               CALCIUM HYDRIDE      NaN            NaN
# 7      Ca(OH)2             CALCIUM HYDROXIDE      NaN            NaN
# 8     Ca(OCl)2          CALCIUM HYPOCHLORITE      NaN            NaN
# 9     Ca(NO3)2               CALCIUM NITRATE      NaN            NaN
# 10         CaO                 CALCIUM OXIDE      NaN            NaN
# 11      CaHPO4    CALCIUM PHOSPHATE, DIBASIC      NaN            NaN
# 12  Ca(H2PO4)2  CALCIUM PHOSPHATE, MONOBASIC      NaN            NaN
# ...

# %%
df["latex"] = df['Formula'].astype(str) +"-"+ df["color"].astype(str)
df
# Out:
#        Formula                        Nombre  W or MW          color  \
# 0           Ca                       CALCIUM   40.078  silvery-white
# 1        CaCO3             CALCIUM CARBONATE  100.090            NaN
# 2         CaC2               CALCIUM CARBIDE   64.100            NaN
# 3        CaCl2              CALCIUM CHLORIDE      NaN            NaN
# 4        CaCN2             CALCIUM CYANAMIDE      NaN            NaN
# 5         CaF2              CALCIUM FLUORIDE   78.075            NaN
# 6         CaH2               CALCIUM HYDRIDE      NaN            NaN
# 7      Ca(OH)2             CALCIUM HYDROXIDE      NaN            NaN
# 8     Ca(OCl)2          CALCIUM HYPOCHLORITE      NaN            NaN
# 9     Ca(NO3)2               CALCIUM NITRATE      NaN            NaN
# 10         CaO                 CALCIUM OXIDE      NaN            NaN
# 11      CaHPO4    CALCIUM PHOSPHATE, DIBASIC      NaN            NaN
# 12  Ca(H2PO4)2  CALCIUM PHOSPHATE, MONOBASIC      NaN            NaN
# ...

# %%
df["latexDos"] = "ch{" + df['Formula'].astype(str) +"}"
df
# Out:
#        Formula                        Nombre  W or MW          color  \
# 0           Ca                       CALCIUM   40.078  silvery-white
# 1        CaCO3             CALCIUM CARBONATE  100.090            NaN
# 2         CaC2               CALCIUM CARBIDE   64.100            NaN
# 3        CaCl2              CALCIUM CHLORIDE      NaN            NaN
# 4        CaCN2             CALCIUM CYANAMIDE      NaN            NaN
# 5         CaF2              CALCIUM FLUORIDE   78.075            NaN
# 6         CaH2               CALCIUM HYDRIDE      NaN            NaN
# 7      Ca(OH)2             CALCIUM HYDROXIDE      NaN            NaN
# 8     Ca(OCl)2          CALCIUM HYPOCHLORITE      NaN            NaN
# 9     Ca(NO3)2               CALCIUM NITRATE      NaN            NaN
# 10         CaO                 CALCIUM OXIDE      NaN            NaN
# 11      CaHPO4    CALCIUM PHOSPHATE, DIBASIC      NaN            NaN
# 12  Ca(H2PO4)2  CALCIUM PHOSPHATE, MONOBASIC      NaN            NaN
# ...

# %%
df['Formula']=df['Formula'].str.replace(r'\D+','',regex=True)
df['Formula']
# Out:
# 0
# 1       3
# 2       2
# 3       2
# 4       2
# 5       2
# 6       2
# 7       2
# 8       2
# 9      32
# 10
# 11      4
# 12    242
# 13    343
# 14      4
# 15
# Name: Formula, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/lib/python3.8/sre_parse.py in parse_template(source, state)
#    1038                 try:
# -> 1039                     this = chr(ESCAPES[this][1])
#    1040                 except KeyError:
#
# KeyError: '\\D'
#
# During handling of the above exception, another exception occurred:
#
# error                                     Traceback (most recent call last)
# <ipython-input-24-e8a4b1c6b093> in <module>
# ----> 1 df['Formula']=df['Formula'].str.replace(r'\D+',r'\D+',regex=True)
#       2 df['Formula']
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/strings/accessor.py in wrapper(self, *args, **kwargs)
#     114                 )
#     115                 raise TypeError(msg)
# --> 116             return func(self, *args, **kwargs)
#     117
#     118         wrapper.__name__ = func_name
#
# ...

# %%
df = pd.DataFrame(['$40,000*','$40000 conditions attached'], columns=['P'])
print(df)
#                             P
# 0                    $40,000*
# 1  $40000 conditions attached

df['P'] = df['P'].str.replace(r'\D+', '', regex=True).astype('int')
print(df)
# Out:
#                             P
# 0                    $40,000*
# 1  $40000 conditions attached
#        P
# 0  40000
# 1  40000
