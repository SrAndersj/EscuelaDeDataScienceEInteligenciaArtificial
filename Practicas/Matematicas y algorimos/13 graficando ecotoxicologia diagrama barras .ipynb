# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt


#import data from excel 
dir='/content/dataEcotoxi.xlsx'

df=pd.read_excel(dir)
df
# Out:
#                        type  GPx 96h  GPx96h+-  GPx15d  GPx15d+-  Unnamed: 5  \
# 0             Water control    0.027     0.006   0.023     0.006         NaN
# 1        Lambda-cyhalothrin    0.034     0.005   0.032     0.005         NaN
# 2           Acetone control    0.036     0.005   0.033     0.004         NaN
# 3                       PBO    0.043     0.006   0.044     0.005         NaN
# 4  Lambda-cyhalothrin + PBO    0.039     0.004   0.053     0.002         NaN
#
#    GR 96h  GR96h+-  GR15d  GR15d+-  ...  Unnamed: 12  GST15d  Unnamed: 14  \
# 0   0.012    0.001  0.011    0.001  ...          NaN   34.67          NaN
# 1   0.013    0.004  0.013    0.001  ...          NaN   60.61          NaN
# 2   0.011    0.001  0.011    0.001  ...          NaN   41.41          NaN
# 3   0.014    0.002  0.018    0.008  ...          NaN   50.10          NaN
# 4   0.013    0.001  0.012      NaN  ...          NaN   53.91          NaN
#
# ...

# %%
# type and GPx 96
t = np.array(df['type'])
g = np.array(df['GPx 96h'])




# temperature= np.array(["A", "B", "C"])

# grafica 1

plt.bar(t,g)


plt.title(' GPx 96 horas   ')
plt.ylabel('UI mg proteina de GPx ')
plt.xlabel(' Experimento')
plt.xticks(rotation=45)
# grafica 2



# plt.ylim(0.02,0.045)




plt.savefig('UI mg proteina de GPx 96 horas .png',bbox_inches = 'tight',dpi=400)   #bbox es para que guarde bien la imagen porque sin el guarda cortada la grafica 



# plt.grid()

plt.show()

# %%
# type and GPx 15 dias
q=np.array(df['GPx15d'])

plt.bar(t,q)


plt.title(' GPx 15 dias ')
plt.ylabel('UI mg proteina de GPx ')
plt.xlabel(' Experimento')
plt.xticks(rotation=45)

plt.savefig('UI mg proteina de GPx 15 dias .png',bbox_inches = 'tight',dpi=400)

# %%
# type and GR 96
t = np.array(df['type'])
g = np.array(df['GR 96h'])




# temperature= np.array(["A", "B", "C"])

# grafica 1

plt.bar(t,g)


plt.title('GR 96 horas ')
plt.ylabel('UI mg proteina de GR ')
plt.xlabel(' Experimento')
plt.xticks(rotation=45)
# grafica 2



# plt.ylim(0.02,0.045)




plt.savefig('UI mg proteina de GR 96 horas .png',bbox_inches = 'tight',dpi=400)   #bbox es para que guarde bien la imagen porque sin el guarda cortada la grafica 



# plt.grid()

plt.show()

# %%
# type and GR 15 dias
q=np.array(df['GR15d'])

plt.bar(t,q)


plt.title('GR 15 dias ')
plt.ylabel('UI mg proteina de GR ')
plt.xlabel(' Experimento')
plt.xticks(rotation=45)

plt.savefig('UI mg proteina de GR 15 dias .png',bbox_inches = 'tight',dpi=400)

# %%
# type and GST 96
t = np.array(df['type'])
g = np.array(df['GST 96h'])




# temperature= np.array(["A", "B", "C"])

# grafica 1

plt.bar(t,g)


plt.title('GST 96 horas ')
plt.ylabel('UI mg proteina de GST ')
plt.xlabel(' Experimento')
plt.xticks(rotation=45)
# grafica 2



# plt.ylim(0.02,0.045)




plt.savefig('UI mg proteina de GST 96 horas .png',bbox_inches = 'tight',dpi=400)   #bbox es para que guarde bien la imagen porque sin el guarda cortada la grafica 



# plt.grid()

plt.show()

# %%
# type and GST 15 dias
q=np.array(df['GST15d'])

plt.bar(t,q)


plt.title('GST 15 dias ')
plt.ylabel('UI mg proteina de GST')
plt.xlabel(' Experimento')
plt.xticks(rotation=45)

plt.savefig('UI mg proteina de GST 15 dias .png',bbox_inches = 'tight',dpi=400)

# %%
# type and tGSH 96
t = np.array(df['type'])
g = np.array(df['tGSH 96h'])




# temperature= np.array(["A", "B", "C"])

# grafica 1

plt.bar(t,g)


plt.title('tGSH    96 horas ')
plt.ylabel('μmol  tGSH /g tejido   ')
plt.xlabel(' Experimento')
plt.xticks(rotation=45)
# grafica 2



# plt.ylim(0.02,0.045)



plt.savefig('μmol  tGSH g tejido   96 horas .png',bbox_inches = 'tight',dpi=400)


# plt.grid()

plt.show()

# %%
# type and tGSH 15 dias
q=np.array(df['tGSH 15d'])

plt.bar(t,q)


plt.title(' tGSH   15 dias ')
plt.ylabel('μmol  tGSH /g tejido ')
plt.xlabel(' Experimento')
plt.xticks(rotation=45)

plt.savefig('μmol  tGSH  g tejido  15 dias  .png',bbox_inches = 'tight',dpi=400)

# %%
# type and GSH 96
t = np.array(df['type'])
g = np.array(df['GSH 96h'])

plt.bar(t,g)


plt.title('GSH    96 horas ')
plt.ylabel('μmol  GSH /g tejido   ')
plt.xlabel(' Experimento')
plt.xticks(rotation=45)


plt.savefig('μmol  GSH  96 h .png',bbox_inches = 'tight',dpi=400)

# %%
# type and GSH 96
t = np.array(df['type'])
g = np.array(df['GSH 15d'])

plt.bar(t,g)


plt.title('GSH    15 días ')
plt.ylabel('μmol  GSH /g tejido   ')
plt.xlabel(' Experimento')
plt.xticks(rotation=45)

plt.savefig('μmol  GSH  15 dias .png',bbox_inches = 'tight',dpi=400)
