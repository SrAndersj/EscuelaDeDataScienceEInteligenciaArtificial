# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt


#import data from excel 
dir='/content/dataMasas.xlsx'

df=pd.read_excel(dir)
df
# Out:
#     PBOx  PBOy
# 0     14    29
# 1     15    38
# 2     19    35
# 3     27   238
# 4     28   213
# ..   ...   ...
# 85   193   587
# 86   194    75
# 87   295   172
# 88   338   389
# 89   339    87
#
# [90 rows x 2 columns]

# %%
# Out:
# 28

# %%
x = np.array(df['PBOx'])
y = np.array(df['PBOy'])

plt.bar(x,y)


plt.title(' Espectro de masas PBO   ')
plt.ylabel('Intensidad Relativa')
plt.xlabel('m/z')

plt.annotate("176", (176, 9999))
plt.annotate("338", (338, 389))

plt.savefig('masasTotal .png',bbox_inches = 'tight',dpi=400)

# %%
x = np.array(df['PBOx'])
y = np.array(df['PBOy'])

plt.bar(x,y)


plt.title(' Espectro de masas PBO   ')
plt.ylabel('Intensidad Relativa')
plt.xlabel('m/z')
plt.xlim(200,)
plt.ylim(0,1000)
plt.annotate("176", (176, 9999))
plt.annotate("338", (338, 389))

plt.savefig('masas 338 .png',bbox_inches = 'tight',dpi=400)
