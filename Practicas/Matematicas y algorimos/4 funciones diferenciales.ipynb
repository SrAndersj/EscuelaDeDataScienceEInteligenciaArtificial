# %% [markdown]
# # Resolver la siguiente ecuacion diferencial
#
# # $\frac{dy}{dx}+3x^{2}y=6x^{2}$

# %%
from sympy import *
init_printing()

# %%
x=symbols("x")
y=Function("y")
x
# Out:
# x

# %%
y(x)
# Out:
# y(x)

# %%
y(x).diff() + x
# Out:
#     d
# x + ──(y(x))
#     dx

# %% [markdown]
# #si yo quisiera que no fuera de primer orden si no segundo orden .diif(x,2)

# %%
3* y(x).diff(x,2)
# Out:
#     2
#    d
# 3⋅───(y(x))
#     2
#   dx

# %% [markdown]
# # vamos a resolver el ejercicio

# %%
Eq(y(x).diff() + 3*x**2 * y(x) ,6*x**2 )
# Out:
#    2        d             2
# 3⋅x ⋅y(x) + ──(y(x)) = 6⋅x
#             dx

# %%
ed = Eq(y(x).diff() + 3*x**2 * y(x) ,6*x**2 )
dsolve(ed,y(x))
# Out:
#              3
#            -x
# y(x) = C₁⋅ℯ    + 2

# %%
# Out:
# y(3)
