# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
dir='/content/dataSafrol.xlsx'

df=pd.read_excel(dir)
df
# Out:
#          nm  absor  cm-1   IRAbsor
# 0    201.82  3.695   450  0.049774
# 1    201.96  3.736   454  0.029671
# 2    202.07  3.779   458  0.001317
# 3    202.33  3.844   462  0.018435
# 4    202.63  3.896   466  0.026335
# ..      ...    ...   ...       ...
# 875     NaN    NaN  3950  0.002546
# 876     NaN    NaN  3954  0.003511
# 877     NaN    NaN  3958  0.003424
# 878     NaN    NaN  3962  0.003248
# 879     NaN    NaN  3966  0.003687
#
# [880 rows x 4 columns]

# %%
#graficando 
fig = plt.figure()
xy=fig.subplots()

#plt.figure(figsize=(4,4))
plot=xy.plot(df['nm'],df['absor'])
xy.set_title('uv-vis Safrol')
xy.set_xlabel('Longitud (nm)')
xy.set_ylabel('Absorbancia')





#guardando jpg
plt.savefig("safrolGood.jpg", dpi=300)
