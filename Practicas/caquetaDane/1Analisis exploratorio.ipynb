# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import seaborn as sns

# %%
import zipfile
import os

# Definimos la ruta al archivo ZIP que queremos descomprimir

zip_path = '/content/drive/MyDrive/ColabNotebooks/EscuelaDeDataScienceEInteligenciaArtificial/Data e Inteligencia Artificial/Practicas/caquetaDane/18_Caqueta/18Caqueta/18_Caqueta_CSV.zip'


# Creamos una carpeta para almacenar los archivos descomprimidos
unzip_folder = '/content/unzip_folder'
if not os.path.exists(unzip_folder):
    os.makedirs(unzip_folder)

# Abrimos el archivo ZIP y lo descomprimimos en la carpeta creada anteriormente
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(unzip_folder)
    
# Imprimimos la lista de archivos descomprimidos
print(os.listdir(unzip_folder))
# Out:
# ['CNPV2018_3FALL_A2_18.CSV', 'CNPV2018_MGN_A2_18.CSV', 'CNPV2018_5PER_A2_18.CSV', 'CNPV2018_1VIV_A2_18.CSV', 'CNPV2018_2HOG_A2_18.CSV']

# %%
#df=pd.read_csv('/content/unzip_folder/CNPV2018_1VIV_A2_18.CSV')
df=pd.read_csv('/content/unzip_folder/CNPV2018_5PER_A2_18.CSV')
df
# Out:
#         TIPO_REG  U_DPTO  U_MPIO  UA_CLASE  COD_ENCUESTAS  U_VIVIENDA  \
# 0              5      18       1         1         401664           1
# 1              5      18       1         1         401664           1
# 2              5      18       1         1         401664           1
# 3              5      18       1         1         401664           1
# 4              5      18       1         1         401664           1
# ...          ...     ...     ...       ...            ...         ...
# 359597         5      18     860         3      902346323           2
# 359598         5      18     860         3      902346323           2
# 359599         5      18     860         3      902346323           2
# 359600         5      18     860         3      902346323           2
# 359601         5      18     860         3      902346447           3
#
#         P_NROHOG  P_NRO_PER  P_SEXO  P_EDADR  ...  PA1_THSV  PA2_HSVH  \
# ...

# %%
df.dtypes
# Out:
# TIPO_REG              int64
# U_DPTO                int64
# U_MPIO                int64
# UA_CLASE              int64
# COD_ENCUESTAS         int64
# U_VIVIENDA            int64
# P_NROHOG            float64
# P_NRO_PER             int64
# P_SEXO                int64
# P_EDADR               int64
# P_PARENTESCOR       float64
# PA1_GRP_ETNIC         int64
# PA11_COD_ETNIA      float64
# PA12_CLAN           float64
# PA21_COD_VITSA      float64
# PA22_COD_KUMPA      float64
# PA_HABLA_LENG       float64
# PA1_ENTIENDE        float64
# PB_OTRAS_LENG       float64
# PB1_QOTRAS_LENG     float64
# PA_LUG_NAC            int64
# PA_VIVIA_5ANOS      float64
# PA_VIVIA_1ANO       float64
# P_ENFERMO           float64
# P_QUEHIZO_PPAL      float64
# PA_LO_ATENDIERON    float64
# PA1_CALIDAD_SERV    float64
# CONDICION_FISICA    float64
# P_ALFABETA          float64
# PA_ASISTENCIA       float64
# P_NIVEL_ANOSR       float64
# P_TRABAJO           float64
# P_EST_CIVIL         float64
# ...

# %%
df.shape
# Out:
# (359602, 48)

# %%
(
    
    df
    .isnull()
    .any()
)
# Out:
# TIPO_REG            False
# U_DPTO              False
# U_MPIO              False
# UA_CLASE            False
# COD_ENCUESTAS       False
# U_VIVIENDA          False
# P_NROHOG             True
# P_NRO_PER           False
# P_SEXO              False
# P_EDADR             False
# P_PARENTESCOR        True
# PA1_GRP_ETNIC       False
# PA11_COD_ETNIA       True
# PA12_CLAN            True
# PA21_COD_VITSA       True
# PA22_COD_KUMPA       True
# PA_HABLA_LENG        True
# PA1_ENTIENDE         True
# PB_OTRAS_LENG        True
# PB1_QOTRAS_LENG      True
# PA_LUG_NAC          False
# PA_VIVIA_5ANOS       True
# PA_VIVIA_1ANO        True
# P_ENFERMO            True
# P_QUEHIZO_PPAL       True
# PA_LO_ATENDIERON     True
# PA1_CALIDAD_SERV     True
# CONDICION_FISICA     True
# P_ALFABETA           True
# PA_ASISTENCIA        True
# P_NIVEL_ANOSR        True
# P_TRABAJO            True
# P_EST_CIVIL          True
# PA_HNV               True
# PA1_THNV             True
# ...

# %%
(
    
    df
    .isnull()
    .sum()
)
# Out:
# TIPO_REG                 0
# U_DPTO                   0
# U_MPIO                   0
# UA_CLASE                 0
# COD_ENCUESTAS            0
# U_VIVIENDA               0
# P_NROHOG             11260
# P_NRO_PER                0
# P_SEXO                   0
# P_EDADR                  0
# P_PARENTESCOR        11260
# PA1_GRP_ETNIC            0
# PA11_COD_ETNIA      350777
# PA12_CLAN           359592
# PA21_COD_VITSA      359581
# PA22_COD_KUMPA      359581
# PA_HABLA_LENG       351136
# PA1_ENTIENDE        356057
# PB_OTRAS_LENG       351136
# PB1_QOTRAS_LENG     357944
# PA_LUG_NAC               0
# PA_VIVIA_5ANOS       11260
# PA_VIVIA_1ANO        11260
# P_ENFERMO            11260
# P_QUEHIZO_PPAL      323384
# PA_LO_ATENDIERON    337077
# PA1_CALIDAD_SERV    338161
# CONDICION_FISICA     11260
# P_ALFABETA           29488
# PA_ASISTENCIA        40707
# P_NIVEL_ANOSR        29488
# P_TRABAJO            74365
# P_EST_CIVIL          63844
# PA_HNV              215893
# ...

# %%
(
    
    df
    .isnull()
    .sum()
    .sum()
)
# Out:
# 8346320

# %%
(
    
    df
    .isnull()
    .melt()

)
# Out:
#               variable  value
# 0             TIPO_REG  False
# 1             TIPO_REG  False
# 2             TIPO_REG  False
# 3             TIPO_REG  False
# 4             TIPO_REG  False
# ...                ...    ...
# 17260891  PA2_ANO_UHNV   True
# 17260892  PA2_ANO_UHNV  False
# 17260893  PA2_ANO_UHNV   True
# 17260894  PA2_ANO_UHNV   True
# 17260895  PA2_ANO_UHNV   True
#
# [17260896 rows x 2 columns]

# %%
(
    
    df
    .isnull()
    .melt()
    .pipe(
        lambda df:(
            sns.displot(
                data=df,
                y='variable',
                hue='value',
                multiple='fill'
                
            )
        )
    )
)

# %%
(
    df
    .isnull()
    .transpose()
    .pipe(
        lambda df:(
            sns.heatmap(
                data=df
            )
        )
    )

)
# Out:
# <Axes: >

# %%
df
# Out:
#         TIPO_REG  U_DPTO  U_MPIO  UA_CLASE  COD_ENCUESTAS  U_VIVIENDA  \
# 0              5      18       1         1         401664           1
# 1              5      18       1         1         401664           1
# 2              5      18       1         1         401664           1
# 3              5      18       1         1         401664           1
# 4              5      18       1         1         401664           1
# ...          ...     ...     ...       ...            ...         ...
# 359597         5      18     860         3      902346323           2
# 359598         5      18     860         3      902346323           2
# 359599         5      18     860         3      902346323           2
# 359600         5      18     860         3      902346323           2
# 359601         5      18     860         3      902346447           3
#
#         P_NROHOG  P_NRO_PER  P_SEXO  P_EDADR  ...  PA1_THSV  PA2_HSVH  \
# ...

# %%
df['P_SEXO']
# Out:
# 0         1
# 1         2
# 2         2
# 3         1
# 4         2
#          ..
# 359597    1
# 359598    2
# 359599    1
# 359600    1
# 359601    2
# Name: P_SEXO, Length: 359602, dtype: int64
