# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_excel('/content/drive/MyDrive/ColabNotebooks/EscuelaDeDataScienceEInteligenciaArtificial/Data e Inteligencia Artificial/Practicas/colegiosPrivadosColombia/correosLimpiosSinNANSinSimbolo.xlsx')
df
# Out:
#                        correo_Electronico  \
# 0             jhonnatan.castano@gmail.com
# 1              pitagoras@pitagoras.edu.co
# 2                  gimfedebel@hotmail.com
# 3     claudialindenibocachica@hotmail.com
# 4               cedalemania12@redp.edu.co
# ...                                   ...
# 2466  jibnuevoreinodeturingia@hotmail.com
# 2467            ruth_ceciliac@hotmail.com
# 2468               pattysantaco@yahoo.com
# 2469             directoragoofy@gmail.com
# 2470           adalgizaladino@hotmail.com
#
#                                   nombreestablecimiento
# 0                                         colegio test
# 1     INST DE BTO TEC COMERCIAL PITAGORAS           ...
# 2                    GIMNASIO INFANTIL FEDERICO FROEBEL
# 3                GIMNASIO INFANTIL LOS NIÑOS DEL MAÑANA
# 4                  COLEGIO FRANCISCO PRIMERO S.S. (IED)
# ...                                                 ...
# 2466                        COL NUEVO REINO DE TURINGIA
# 2467                        COL NUEVO REINO DE TURINGIA
# 2468  LIC  INF GOOFY                                ...
# 2469  LIC  INF GOOFY                                ...
# 2470  JARD INF EL ROSAL DE MI INFANCIA              ...
#
# [2471 rows x 2 columns]

# %% [markdown]
# # filtro solo 56
#
# 0 56 112 168 224  257

# %%
df=pd.read_excel('/content/drive/MyDrive/ColabNotebooks/EscuelaDeDataScienceEInteligenciaArtificial/Data e Inteligencia Artificial/Practicas/colegiosPrivadosColombia/correosLimpiosSinNANSinSimbolo.xlsx')


inicio = input('Ingresa un valor para la variable inicio: ')
inicioINT = int(inicio)

final = inicioINT + int(55)
finalINT = int(final)

nuevo_df = df.iloc[inicioINT:finalINT]
nuevo_df.reset_index(drop=True, inplace=True)
# Out:
# Ingresa un valor para la variable inicio: 275

# %%
# Mostrar el nuevo DataFrame
df=nuevo_df
nuevo_df
# Out:
#                                    correo_Electronico  \
# 0                           thomasiriarte@hotmail.com
# 1           cdfl50@colegiodiegofallonlasallano.edu.co
# 2                   culturalciudadkennedy@hotmail.com
# 3                              marmorenos@hotmail.com
# 4                                iedjulio@redp.edu.co
# 5                       cedlaflorestasur8@redp.edu.co
# 6                             colcalifornia@gmail.com
# 7   colegioceicnorte.secretariaacademica@colsubsid...
# 8                   colegio.ceicnorte@colsubsidio.com
# 9                                cebilbao@hotmail.com
# 10                                 colpam@hotmail.com
# 11                              oscar89tc@hotmail.com
# 12                              tutiperry@hotmail.com
# 13                     cededuardosantos14@redp.edu.co
# 14                         info@americangarden.edu.co
# 15                     colmarruecosymolinos@gmail.com
# 16                             coljmvyv@latinmail.com
# 17                                 coljmvyv@gmail.com
# 18             coldiruraljosecelestinomutis@gmail.com
# 19                      liceomariavictoria2@yahoo.com
# 20                          portadoresdeluz@terra.com
# 21                         liceo_gran_virrey@yahoo.es
# 22                            granvirrey@007mundo.com
# 23                           cdifontibon9@redp.edu.co
# 24               liceoinfantilsantarita72@hotmail.com
# 25                  colegiotomasalvaedison@etb.com.co
# 26                         escdimarandu19@redp.edu.co
# 27                   escdiparaisomirado19@redp.edu.co
# 28                          liceomagico2002@yahoo.com
# 29                   rectoriacolegio@colsanter.edu.co
# 30                        secretaria@colsanter.edu.co
# 31                    coldirepdecostaric9@redp.edu.co
# 32                                         mcrisvegah
# 33                                          @yahoo.es
# 34                      cedinternacional9@redp.edu.co
# 35                           ceditintern9@redp.edu.co
# 36                 dircentro@sanricardopampuri.org.co
# 37                   dircentro@sanriccardopampuri.com
# 38                         cedelporvenir7@redp.edu.co
# 39                         taticachaparro@hotmail.com
# 40                         colegioateniense@yahoo.com
# 41                     coordinacionateniense@yahoo.es
# 42                     iedjoseantoniogalan7@gmail.com
# 43                          liceomoravia@terra.com.co
# 44                                   colcmbs@yahoo.es
# 45                   colpsicoarnoldgesell@hotmail.com
# 46                    coldidarioechandia8@redp.edu.co
# 47                             liceostomasmp@yahoo.es
# 48                             horizontes99@yahoo.com
# 49               gimnasiomodernojhonneper@hotmail.com
# 50                         eltrendemickey@hotmail.com
# 51                    centroserviciosdoc4@redp.edu.co
# 52                      cedsimonbolivar11@redp.edu.co
# 53              colegiorealdecolombia2010@hotmail.com
# 54                       liceomallerland6@hotmail.com
#
#                                 nombreestablecimiento
# 0   LIC INF THOMAS DE IRIARTE                     ...
# 1   COL DIEGO FALLON  LASALLANO                   ...
# 2   INST CULT CIUDAD KENNEDY                      ...
# 3   INST CULT CIUDAD KENNEDY                      ...
# 4                 COLEGIO JULIO GARAVITO ARMERO (IED)
# 5                       COLEGIO LA FLORESTA SUR (IED)
# 6   COL CALIFORNIA                                ...
# 7                           COLEGIO COLSUBSIDIO NORTE
# 8                           COLEGIO COLSUBSIDIO NORTE
# 9   JARD INF MALU Y YO                            ...
# 10  COL SUR ORIENTAL PANAMERICANO                 ...
# 11                 COLEGIO MARIO LUIS RODRIGUEZ COBOS
# 12  JARD INF CARACOLITO                           ...
# 13                       COLEGIO EDUARDO SANTOS (IED)
# 14  JARD INF AMERICANO                            ...
# 15  LIC LUIS CARDONA CARVAJAL                     ...
# 16  COL JOSE MARIA VERGARA Y VERGARA              ...
# 17  COL JOSE MARIA VERGARA Y VERGARA              ...
# 18  COL JOSE MARIA VERGARA Y VERGARA              ...
# 19  LIC  MARIA VICTORIA                           ...
# 20  JARD INF PORTADORES DE LUZ LTDA               ...
# 21  LIC EL GRAN VIRREY                            ...
# 22  LIC EL GRAN VIRREY                            ...
# 23          COLEGIO INTEGRADO DE FONTIBON IBEP  (IED)
# 24  COL PARROQ MONSEÑOR EMILIO DE BRIGARD         ...
# 25  COL TOMAS ALVA EDISON                         ...
# 26                             COLEGIO VILLAMAR (IED)
# 27                      COLEGIO PARAISO MIRADOR (IED)
# 28  LIC MI VIVIR MAGICO                           ...
# 29  COL SANTA TERESA DE JESUS                     ...
# 30  COL SANTA TERESA DE JESUS                     ...
# 31                          COLEGIO COSTA RICA  (IED)
# 32  LIC EL MUNDO DE LOS NIÑOS                     ...
# 33  LIC EL MUNDO DE LOS NIÑOS                     ...
# 34     COLEGIO INSTITUTO TECNICO INTERNACIONAL  (IED)
# 35     COLEGIO INSTITUTO TECNICO INTERNACIONAL  (IED)
# 36  CENT EDUC INTEGRAL SAN RICCARDO PAMPURI       ...
# 37  CENT EDUC INTEGRAL SAN RICCARDO PAMPURI       ...
# 38                          COLEGIO EL PORVENIR (IED)
# 39  JARD INF COQUITO                              ...
# 40  COL ATENIENSE (ANTES INST MODERNO ATHENAS)    ...
# 41  COL ATENIENSE (ANTES INST MODERNO ATHENAS)    ...
# 42                   COLEGIO JOSE ANTONIO GALAN (IED)
# 43  LIC JUVENIL DE MORAVIA                        ...
# 44  COL MONSEÑOR BERNARDO SANCHEZ  HNAS DE NSTRA S...
# 45  COL PSICOPEDAG ARNOLD GESELL                  ...
# 46                       COLEGIO DARIO ECHANDIA (IED)
# 47  LIC INTEGRAL SANTO TOMAS                      ...
# 48  LIC  NUEVOS HORIZONTES                        ...
# 49  GIMN MODERNO JHON NEPER                       ...
# 50                  LICEO PEDAGOGICO PROYECTO DE VIDA
# 51                 COLEGIO ALDEMAR ROJAS PLAZAS (IED)
# 52            COLEGIO FILARMONICO SIMON BOLIVAR (IED)
# 53                               COL REAL DE COLOMBIA
# 54  LIC MALLERLAND                                ...

# %% [markdown]
# # envio correo

# %% [markdown]
# # copiar los pdf

# %%
import shutil

# Ruta de la carpeta de origen
ruta_origen = '/content/drive/MyDrive/ColabNotebooks/EscuelaDeDataScienceEInteligenciaArtificial/Data e Inteligencia Artificial/Practicas/colegiosPrivadosColombia/'

# Ruta de destino
ruta_destino = '/content/'

# Lista de archivos a copiar
archivos = ['Hoja de vida.pdf', 'Carta de presentación profe Jhonnatan Andrés Castaño Rojas.pdf']

# Copiar los archivos
for archivo in archivos:
    ruta_fuente = ruta_origen + archivo
    shutil.copy2(ruta_fuente, ruta_destino)

# %%
# !ls *.pdf
# Out:
# 'Carta de presentación profe Jhonnatan Andrés Castaño Rojas.pdf'
# 'Hoja de vida.pdf'

# %% [markdown]
# # creando imagenes no duplicadas

# %%
from PIL import Image, ImageDraw, ImageFont
import pandas as pd



# configurar la imagen
width, height = 1920, 1080
background_color = '#FFFFFF'
font_color = '#000000'
font_size = 30
font_type = '/usr/share/fonts/truetype/liberation/LiberationSans-Regular.ttf'
line_spacing = 50  # agregar 2 cm (50 pixeles) adicionales
espaciadoEnVertical = 220

# abrir la fuente
font = ImageFont.truetype(font_type, font_size)

# crear un conjunto para almacenar los nombres de colegio procesados
nombres_procesados = set()

# iterar a través de cada fila del DataFrame
for index, row in df.iterrows():
    nombre_colegio = row["nombreestablecimiento"]
    
    # verificar si el nombre del colegio ya ha sido procesado
    if nombre_colegio in nombres_procesados:
        continue  # pasar a la siguiente fila
    
    # agregar el nombre del colegio al conjunto de nombres procesados
    nombres_procesados.add(nombre_colegio)

    # crear la imagen
    image = Image.open('/content/drive/MyDrive/ColabNotebooks/EscuelaDeDataScienceEInteligenciaArtificial/Data e Inteligencia Artificial/Practicas/colegiosPrivadosColombia/portada.png')

    # agregar el texto
    draw = ImageDraw.Draw(image)
    presentacion = "Presentación hecha para:"
    text = f"{presentacion} {nombre_colegio}"
    
    # calcular la posición del texto en la imagen
    text_width, text_height = draw.textsize(text, font=font)
    x = (width - text_width) // 2
    y = (height - text_height) // 2 + espaciadoEnVertical
    
    # escribir el texto en la imagen
    draw.text((x, y), text, font=font, fill=font_color)
    
    # agregar espacio adicional debajo del texto
    y += text_height + line_spacing

    # guardar la imagen
    image.save(f'{nombre_colegio}.png')

# %% [markdown]
# # credenciales y envio

# %%
import smtplib

smtp_server = "smtp.gmail.com"
smtp_port = 587
smtp_username = ""
smtp_password = ""

smtp_connection = smtplib.SMTP(smtp_server, smtp_port)
smtp_connection.starttls()
smtp_connection.login(smtp_username, smtp_password)
# Out:
# (235, b'2.7.0 Accepted')

# %%
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.application import MIMEApplication
from email.mime.image import MIMEImage

contador = 0
errores = []

for index, row in df.iterrows():
    establecimiento = row['nombreestablecimiento']
    correo_electronico = row['correo_Electronico']
    imagen = f"{establecimiento}.png"
    archivo_pdf = "Hoja de vida.pdf"
    carta_presentacion_pdf = "Carta de presentación profe Jhonnatan Andrés Castaño Rojas.pdf"
    codigo_pdf = "Hoja de vida.pdf"
    
    message = MIMEMultipart()
    message['From'] = smtp_username
    message['To'] = correo_electronico
    message['Subject'] = "Hoja de Vida Docente de Química"
    
    # Cuerpo del correo
    saludo = f"Hola, {establecimiento}.\n\n"
    cuerpo_correo = f"""
    
Espero quien reciba éste correo se encuentre bien.SoyJhonnatan Andres Castaño Rojas

estoy muy entusiasmado por la oportunidad de postularme como profesor de Química en
su prestigioso colegio.Permítame comenzar presentándome brevemente.Soy Químico  y 
amo nutrir y hacer crecer el Talento y
fomentar la curiosidad y amor por la ciencia.

El propósito de este correo electrónico es solicitar la oportunidad de unirme al equipo docente de {establecimiento}. 

Creo firmemente que mi experiencia y pasión por la enseñanza de la Química pueden contribuir 
significativamente al éxito de los estudiantes en su colegio.

Además, me complace compartir con ustedes que, como parte de mi enfoque en la eficiencia y la automatización,
he desarrollado una herramienta personalizada utilizando el lenguaje de programación Python.Esta herramienta
me ha permitido extraer automáticamente los nombres y correos electrónicos de colegios con el fin de agilizar
y facilitar el proceso de envío de mi hoja de vida como la presente.Al utilizar esta herramienta, he logrado 
llegar a una amplia gama de colegios de manera eficiente y efectiva y creo que la enseñanza en éste siglo debe
unir la ciencia y la tecnología.


Agradezco de antemano la oportunidad de considerar mi solicitud y estaré encantado de proporcionar más 
detalles sobre mi experiencia y mis habilidades pedagógicas en una entrevista personal.Adjunto a este 
correo encontrará mi Carta de presentacion y mi hoja de vida de Linkedin(SrAndersj :https://www.linkedin.com/in/sranders/ ),donde podrá obtener 
más información sobre mi formación académica, experiencia laboral y logros relevantes.

Aprovecho esta ocasión para expresar mi gratitud por su tiempo y consideración.Quedo a su disposición 
para responder cualquier pregunta adicional o proporcionar cualquier información adicional que puedan requerir.
Espero con entusiasmo la posibilidad de unirme al equipo de educadores de {establecimiento} y contribuir al 
crecimiento y éxito continuo de sus estudiantes.

Atentamente,

Jhonnatan Andres Castaño Rojas
321 946 50 22
jhonnatan.castano.documentos@gmail.com.


Mensaje enviado mediante codigo en python, si observa un error por favor notifiquelo en redes sociales o github SrAndersj 

Construyamos juntos el Código que transfome nuestro pais y lo haga prospero y lleno de oportunidades mediante la Ciencia y la Tecnología

"""
    cuerpo_correo = saludo + cuerpo_correo
    text = MIMEText(cuerpo_correo)
    message.attach(text)
    
    # Imagen adjunta
    with open(imagen, 'rb') as f:
        img_data = f.read()
    image = MIMEImage(img_data, name=imagen)
    message.attach(image)
    
    # Archivo PDF adjunto - Hoja de vida
    with open(archivo_pdf, 'rb') as f:
        pdf_data = f.read()
    pdf = MIMEApplication(pdf_data, name=archivo_pdf)
    message.attach(pdf)
    
    # Archivo PDF adjunto - Carta de presentacion
    with open(carta_presentacion_pdf, 'rb') as f:
        carta_data = f.read()
    carta = MIMEApplication(carta_data, name=carta_presentacion_pdf)
    message.attach(carta)

   

    
    # Envío del correo
    smtp_connection.send_message(message)

    try:
        # Envío del correo
        smtp_connection.send_message(message)
        contador += 1
    except Exception as e:
        # Capturar el error y guardar el nombre del colegio
        errores.append(establecimiento)
        print(f"Error al enviar el correo al colegio: {establecimiento}. Error: {str(e)}")

print(f"Se enviaron {contador} mensajes.")
print(f"Colegios con error: {errores}")
# Out:
# ---------------------------------------------------------------------------
# SMTPRecipientsRefused                     Traceback (most recent call last)
# <ipython-input-24-62268c966e3c> in <cell line: 9>()
#      92
#      93     # Envío del correo
# ---> 94     smtp_connection.send_message(message)
#      95
#      96     try:
#
# /usr/lib/python3.10/smtplib.py in send_message(self, msg, from_addr, to_addrs, mail_options, rcpt_options)
#     984             g.flatten(msg_copy, linesep='\r\n')
#     985             flatmsg = bytesmsg.getvalue()
# --> 986         return self.sendmail(from_addr, to_addrs, flatmsg, mail_options,
#     987                              rcpt_options)
#     988
#
# /usr/lib/python3.10/smtplib.py in sendmail(self, from_addr, to_addrs, msg, mail_options, rcpt_options)
#     899             # the server refused all our recipients
#     900             self._rset()
# --> 901             raise SMTPRecipientsRefused(senderrs)
#     902         (code, resp) = self.data(msg)
#     903         if code != 250:
#
# SMTPRecipientsRefused: {'mcrisvegah': (553, b'5.1.3 The recipient address <mcrisvegah> is not a valid RFC-5321 address.\n5.1.3 Learn more at\n5.1.3  https://support.google.com/mail/answer/6596 g36-20020a028527000000b004165289bf0csm8603757jai.168 - gsmtp')}

# %%
print(f"Se enviaron {contador} mensajes.")
print(f"Colegios con error: {errores}")
# Out:
# Se enviaron 50 mensajes.
# Colegios con error: []

# %% [markdown]
# # borrar todos los png

# %%
import os

# Obtener la lista de archivos en la ruta
files = os.listdir('/content/')

# Recorrer los archivos y borrar aquellos que tengan la extensión .png
for file in files:
    if file.endswith('.png'):
        os.remove(os.path.join('/content/', file))

# %%
import pandas as pd

# Crear un DataFrame de ejemplo
data = {
    'nombreestablecimiento': ['Colegio A', 'Colegio B', 'Colegio C', 'Colegio D'],
    'correo_Electronico': ['colegioA@hotmail.com', 'colegioB@latinmail.com', 'colegioC@hotmail.com -- colegioC@latinmail.com', 'colegioD@gmail.com -- colegioD@hotmail.com']
}

df = pd.DataFrame(data)

# Función para separar correos electrónicos repetidos en diferentes filas
def separar_correos(row):
    correos = str(row['correo_Electronico'])  # Convertir a cadena de texto
    if '--' in correos:
        correos = correos.split('--')
        correos = [correo.strip() for correo in correos]
    else:
        correos = [correos.strip()]  # Si no hay '--', agregar el correo como está
    return pd.Series(correos)


# Aplicar la función a cada fila del DataFrame
df = df.apply(separar_correos, axis=1).stack().reset_index(level=1, drop=True).to_frame('correo_Electronico').join(df['nombreestablecimiento'])

# Mostrar el DataFrame resultante
print(df)

# %%
import pandas as pd

# DataFrame con los datos de ejemplo
data = {
    'nombreestablecimiento': ['Colegio A', 'Colegio A', 'Colegio B', 'Colegio B', 'Colegio C'],
    'correo_Electronico': ['correo1@colegioa.com', 'correo2@colegioa.com', 'correo1@colegiob.com', 'correo2@colegiob.com', 'correo1@colegioc.com']
}

df = pd.DataFrame(data)

df
# Out:
#   nombreestablecimiento    correo_Electronico
# 0             Colegio A  correo1@colegioa.com
# 1             Colegio A  correo2@colegioa.com
# 2             Colegio B  correo1@colegiob.com
# 3             Colegio B  correo2@colegiob.com
# 4             Colegio C  correo1@colegioc.com

# %%
# Función para combinar los correos electrónicos
def combinar_correos(group):
    return ', '.join(group)

# Aplicar el group by y combinar los correos electrónicos
df_grouped = df.groupby('nombreestablecimiento')['correo_Electronico'].apply(combinar_correos).reset_index()

# Mostrar el DataFrame resultante
df_grouped
# Out:
#   nombreestablecimiento                          correo_Electronico
# 0             Colegio A  correo1@colegioa.com, correo2@colegioa.com
# 1             Colegio B  correo1@colegiob.com, correo2@colegiob.com
# 2             Colegio C                        correo1@colegioc.com
