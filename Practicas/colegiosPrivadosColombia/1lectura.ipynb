# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # import data set
#
#
# ## data proveniente de
#
# https://www.datos.gov.co/Educaci-n/COLEGIOS-PRIVADOS-Y-OFICIALES/d64g-7qfy

# %%
df=pd.read_csv('/content/drive/MyDrive/ColabNotebooks/EscuelaDeDataScienceEInteligenciaArtificial/Data e Inteligencia Artificial/Practicas/colegiosPrivadosColombia/COLEGIOS_PRIVADOS_Y_OFICIALES.csv')
df
# Out:
#        año secretaria                              nombreestablecimiento  \
# 0     2016     BOGOTA  INST DE BTO TEC COMERCIAL PITAGORAS           ...
# 1     2016     BOGOTA                 GIMNASIO INFANTIL FEDERICO FROEBEL
# 2     2016     BOGOTA             GIMNASIO INFANTIL LOS NIÑOS DEL MAÑANA
# 3     2016     BOGOTA               COLEGIO FRANCISCO PRIMERO S.S. (IED)
# 4     2016     BOGOTA  COL SAN JUAN VIANETH                          ...
# ...    ...        ...                                                ...
# 2399  2016     BOGOTA                       COLEGIO SAN JOSE DE CALASANZ
# 2400  2016     BOGOTA                        COL NUEVO REINO DE TURINGIA
# 2401  2016     BOGOTA  LIC  INF GOOFY                                ...
# 2402  2016     BOGOTA  LIC APRENDO CON MIS AMIGOS                    ...
# 2403  2016     BOGOTA  JARD INF EL ROSAL DE MI INFANCIA              ...
#
#         zona             direccion                              telefono  \
# ...

# %% [markdown]
# # what type of data are the variables in the data set?

# %%
df.dtypes
# Out:
# año                            int64
# secretaria                    object
# nombreestablecimiento         object
# zona                          object
# direccion                     object
# telefono                      object
# nombre_Rector                 object
# tipo_Establecimiento          object
# etnias                        object
# sector                       float64
# genero                       float64
# niveles                       object
# jornadas                      object
# caracter                     float64
# especialidad                  object
# grados                        object
# modelos_Educativos            object
# capacidades_Excepcionales     object
# discapacidades                object
# idiomas                       object
# numero_de_Sedes                int64
# estado                       float64
# prestador_de_Servicio         object
# propiedad_Planta_Fisica       object
# resguardo                     object
# ...

# %% [markdown]
# # How many variables of each data type do we have in the data set?

# %%
(
    df
    .dtypes
    .value_counts()
)
# Out:
# object     23
# float64     5
# int64       2
# dtype: int64

# %%
df['secretaria'].value_counts()
# Out:
# BOGOTA    2404
# Name: secretaria, dtype: int64

# %% [markdown]
# # of the types of establishments, how many are there for each?

# %%
df['tipo_Establecimiento'].value_counts()
# Out:
# INSTITUCION EDUCATIVA    1227
# CENTRO EDUCATIVO         1177
# Name: tipo_Establecimiento, dtype: int64

# %% [markdown]
# # Are there explicit null values in the data set?

# %%
(
    df
    .isnull()
    .any()
)
# Out:
# año                          False
# secretaria                   False
# nombreestablecimiento        False
# zona                         False
# direccion                    False
# telefono                      True
# nombre_Rector                False
# tipo_Establecimiento         False
# etnias                        True
# sector                        True
# genero                        True
# niveles                       True
# jornadas                      True
# caracter                      True
# especialidad                  True
# grados                        True
# modelos_Educativos            True
# capacidades_Excepcionales     True
# discapacidades                True
# idiomas                       True
# numero_de_Sedes              False
# estado                        True
# prestador_de_Servicio        False
# propiedad_Planta_Fisica      False
# resguardo                    False
# matricula_Contratada         False
# calendario                   False
# ...

# %% [markdown]
# # If we have observations with null values, how many do we have for each variable?

# %%
(
    df
    .isnull()
    .sum()
)
# Out:
# año                             0
# secretaria                      0
# nombreestablecimiento           0
# zona                            0
# direccion                       0
# telefono                       62
# nombre_Rector                   0
# tipo_Establecimiento            0
# etnias                       2333
# sector                       2404
# genero                       2404
# niveles                        16
# jornadas                       13
# caracter                     2404
# especialidad                 1110
# grados                         16
# modelos_Educativos             38
# capacidades_Excepcionales    2394
# discapacidades               1890
# idiomas                      1461
# numero_de_Sedes                 0
# estado                       2404
# prestador_de_Servicio           0
# propiedad_Planta_Fisica         0
# resguardo                       0
# matricula_Contratada            0
# calendario                      0
# ...

# %% [markdown]
# # How many null values do we have in total in the data set?

# %%
(
    df
    .isnull()
    .sum()
    .sum()
)
# Out:
# 24181

# %% [markdown]
# # What is the proportion of null values for each variable?

# %%
(
    df
    .isnull()
    .melt()
)
# Out:
#                  variable  value
# 0                     año  False
# 1                     año  False
# 2                     año  False
# 3                     año  False
# 4                     año  False
# ...                   ...    ...
# 72115  correo_Electronico  False
# 72116  correo_Electronico  False
# 72117  correo_Electronico  False
# 72118  correo_Electronico   True
# 72119  correo_Electronico  False
#
# [72120 rows x 2 columns]

# %%
(
    df
    .isnull()
    .melt()
    .pipe(
        lambda df:(
            sns.displot(
                data=df,
                y='variable',
                hue='value',
                multiple='fill'
            )
        )
    )
)

# %%
df['jornadas']
# Out:
# 0                 COMPLETA
# 1                 COMPLETA
# 2                 COMPLETA
# 3       MAÑANA,ÚNICA,TARDE
# 4          MAÑANA,COMPLETA
#                ...
# 2399              COMPLETA
# 2400              COMPLETA
# 2401              COMPLETA
# 2402              COMPLETA
# 2403                MAÑANA
# Name: jornadas, Length: 2404, dtype: object

# %%
df['jornadas'].value_counts()
# Out:
# COMPLETA                                        1418
# MAÑANA,TARDE                                     206
# MAÑANA                                           170
# MAÑANA,COMPLETA                                  148
# MAÑANA,ÚNICA,TARDE                                73
# MAÑANA,NOCTURNA,FIN DE SEMANA                     48
# MAÑANA,COMPLETA,TARDE                             36
# MAÑANA,NOCTURNA,TARDE                             34
# COMPLETA,TARDE                                    27
# ÚNICA                                             20
# COMPLETA,ÚNICA                                    19
# NOCTURNA,FIN DE SEMANA                            17
# MAÑANA,ÚNICA,NOCTURNA,TARDE                       15
# MAÑANA,NOCTURNA,TARDE,FIN DE SEMANA               15
# MAÑANA,ÚNICA                                      15
# MAÑANA,COMPLETA,ÚNICA,TARDE                       12
# COMPLETA,NOCTURNA                                 12
# COMPLETA,FIN DE SEMANA                            10
# ...

# %%
df['correo_Electronico']
# Out:
# 0                              pitagoras@pitagoras.edu.co
# 1                                  gimfedebel@hotmail.com
# 2                     claudialindenibocachica@hotmail.com
# 3                               cedalemania12@redp.edu.co
# 4       colegiosanjuanviateh@hotmail.com -- colegiosan...
#                               ...
# 2399                                    csjcsuba@yahoo.es
# 2400    jibnuevoreinodeturingia@hotmail.com - ruth_cec...
# 2401    pattysantaco@yahoo.com   directoragoofy@gmail....
# 2402                                                  NaN
# 2403    adalgizaladino@hotmail.com                    ...
# Name: correo_Electronico, Length: 2404, dtype: object

# %%
df[['nombreestablecimiento','correo_Electronico']]
# Out:
#                                   nombreestablecimiento  \
# 0     INST DE BTO TEC COMERCIAL PITAGORAS           ...
# 1                    GIMNASIO INFANTIL FEDERICO FROEBEL
# 2                GIMNASIO INFANTIL LOS NIÑOS DEL MAÑANA
# 3                  COLEGIO FRANCISCO PRIMERO S.S. (IED)
# 4     COL SAN JUAN VIANETH                          ...
# ...                                                 ...
# 2399                       COLEGIO SAN JOSE DE CALASANZ
# 2400                        COL NUEVO REINO DE TURINGIA
# 2401  LIC  INF GOOFY                                ...
# 2402  LIC APRENDO CON MIS AMIGOS                    ...
# 2403  JARD INF EL ROSAL DE MI INFANCIA              ...
#
#                                      correo_Electronico
# 0                            pitagoras@pitagoras.edu.co
# 1                                gimfedebel@hotmail.com
# 2                   claudialindenibocachica@hotmail.com
# 3                             cedalemania12@redp.edu.co
# ...

# %%
df[['nombreestablecimiento','correo_Electronico','telefono','prestador_de_Servicio']].head(100)
# Out:
#                                 nombreestablecimiento  \
# 0   INST DE BTO TEC COMERCIAL PITAGORAS           ...
# 1                  GIMNASIO INFANTIL FEDERICO FROEBEL
# 2              GIMNASIO INFANTIL LOS NIÑOS DEL MAÑANA
# 3                COLEGIO FRANCISCO PRIMERO S.S. (IED)
# 4   COL SAN JUAN VIANETH                          ...
# ..                                                ...
# 95                              COLEGIO TABORA  (IED)
# 96                                COLEGIO FRANCISCO I
# 97  LIC BOTERITOS                                 ...
# 98                   COLEGIO DE CULTURA POPULAR (IED)
# 99   COLEGIO LOS COMUNEROS - OSWALDO GUAYAZAMIN (IED)
#
#                                    correo_Electronico             telefono  \
# 0                          pitagoras@pitagoras.edu.co  5665677   / 3429092
# 1                              gimfedebel@hotmail.com              7100349
# 2                 claudialindenibocachica@hotmail.com              6010350
# ...

# %%
df['nombreestablecimiento'][0]
# Out:
# 'INST DE BTO TEC COMERCIAL PITAGORAS                                                                 '

# %%
df[['nombreestablecimiento','correo_Electronico','telefono','prestador_de_Servicio']].iloc[:20]
# Out:
#                                 nombreestablecimiento  \
# 0   INST DE BTO TEC COMERCIAL PITAGORAS           ...
# 1                  GIMNASIO INFANTIL FEDERICO FROEBEL
# 2              GIMNASIO INFANTIL LOS NIÑOS DEL MAÑANA
# 3                COLEGIO FRANCISCO PRIMERO S.S. (IED)
# 4   COL SAN JUAN VIANETH                          ...
# 5   COL SAN PATRICIO                              ...
# 6   COL CRISTIANO FUENTE DE VIDA                  ...
# 7   LIC PARROQ SAN JOSE                           ...
# 8   LIC ESTRELLITA ESTUDIANTIL                    ...
# 9                                COL LUIGI PIRANDELLO
# 10  JARDIN INFANTIL CAMPESTRE MI BELLA IMAGEN     ...
# 11                   COLEGIO MARCO FIDEL SUAREZ (IED)
# 12  INST ORESTES SINDICI                          ...
# 13  COL DEL BOSQUE                                ...
# 14  INST SANTA INES                               ...
# 15                        CENTRO DE EDUCACION LABORAL
# ...
