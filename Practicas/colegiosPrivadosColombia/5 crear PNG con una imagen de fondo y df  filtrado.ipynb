# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('/content/drive/MyDrive/ColabNotebooks/EscuelaDeDataScienceEInteligenciaArtificial/Data e Inteligencia Artificial/Practicas/colegiosPrivadosColombia/COLEGIOS_PRIVADOS_Y_OFICIALES.csv')
df.head(10)
# Out:
#     año secretaria                              nombreestablecimiento    zona  \
# 0  2016     BOGOTA  INST DE BTO TEC COMERCIAL PITAGORAS           ...  URBANA
# 1  2016     BOGOTA                 GIMNASIO INFANTIL FEDERICO FROEBEL  URBANA
# 2  2016     BOGOTA             GIMNASIO INFANTIL LOS NIÑOS DEL MAÑANA  URBANA
# 3  2016     BOGOTA               COLEGIO FRANCISCO PRIMERO S.S. (IED)  URBANA
# 4  2016     BOGOTA  COL SAN JUAN VIANETH                          ...  URBANA
# 5  2016     BOGOTA  COL SAN PATRICIO                              ...  URBANA
# 6  2016     BOGOTA  COL CRISTIANO FUENTE DE VIDA                  ...  URBANA
# 7  2016     BOGOTA  LIC PARROQ SAN JOSE                           ...  URBANA
# 8  2016     BOGOTA  LIC ESTRELLITA ESTUDIANTIL                    ...  URBANA
# 9  2016     BOGOTA                               COL LUIGI PIRANDELLO  URBANA
#
#               direccion             telefono  \
# 0            KR 5 11 67  5665677   / 3429092
# ...

# %%
df_personas_naturales = df[df['prestador_de_Servicio'] == 'PERSONA NATURAL']
df=df_personas_naturales
df
# Out:
#        año secretaria                              nombreestablecimiento  \
# 0     2016     BOGOTA  INST DE BTO TEC COMERCIAL PITAGORAS           ...
# 1     2016     BOGOTA                 GIMNASIO INFANTIL FEDERICO FROEBEL
# 2     2016     BOGOTA             GIMNASIO INFANTIL LOS NIÑOS DEL MAÑANA
# 4     2016     BOGOTA  COL SAN JUAN VIANETH                          ...
# 5     2016     BOGOTA  COL SAN PATRICIO                              ...
# ...    ...        ...                                                ...
# 2395  2016     BOGOTA  LIC PEDAG CIENCIA Y CULTURA                   ...
# 2400  2016     BOGOTA                        COL NUEVO REINO DE TURINGIA
# 2401  2016     BOGOTA  LIC  INF GOOFY                                ...
# 2402  2016     BOGOTA  LIC APRENDO CON MIS AMIGOS                    ...
# 2403  2016     BOGOTA  JARD INF EL ROSAL DE MI INFANCIA              ...
#
#         zona             direccion                              telefono  \
# ...

# %%
# reemplazar la abreviatura 'COL' por la palabra 'COLEGIO'
df['nombreestablecimiento'] = df['nombreestablecimiento'].str.replace('COL', 'COLEGIO')

df
# Out:
#        año secretaria                              nombreestablecimiento  \
# 0     2016     BOGOTA  INST DE BTO TEC COMERCIAL PITAGORAS           ...
# 1     2016     BOGOTA                 GIMNASIO INFANTIL FEDERICO FROEBEL
# 2     2016     BOGOTA             GIMNASIO INFANTIL LOS NIÑOS DEL MAÑANA
# 4     2016     BOGOTA  COLEGIO SAN JUAN VIANETH                      ...
# 5     2016     BOGOTA  COLEGIO SAN PATRICIO                          ...
# ...    ...        ...                                                ...
# 2395  2016     BOGOTA  LIC PEDAG CIENCIA Y CULTURA                   ...
# 2400  2016     BOGOTA                    COLEGIO NUEVO REINO DE TURINGIA
# 2401  2016     BOGOTA  LIC  INF GOOFY                                ...
# 2402  2016     BOGOTA  LIC APRENDO CON MIS AMIGOS                    ...
# 2403  2016     BOGOTA  JARD INF EL ROSAL DE MI INFANCIA              ...
#
#         zona             direccion                              telefono  \
# ...

# %%
# listado de fuentes
# !ls /usr/share/fonts/truetype/
# Out:
# humor-sans  liberation

# %%
# !ls /usr/share/fonts/truetype/liberation
# Out:
# LiberationMono-BoldItalic.ttf	     LiberationSansNarrow-Bold.ttf
# LiberationMono-Bold.ttf		     LiberationSansNarrow-Italic.ttf
# LiberationMono-Italic.ttf	     LiberationSansNarrow-Regular.ttf
# LiberationMono-Regular.ttf	     LiberationSans-Regular.ttf
# LiberationSans-BoldItalic.ttf	     LiberationSerif-BoldItalic.ttf
# LiberationSans-Bold.ttf		     LiberationSerif-Bold.ttf
# LiberationSans-Italic.ttf	     LiberationSerif-Italic.ttf
# LiberationSansNarrow-BoldItalic.ttf  LiberationSerif-Regular.ttf

# %%
pip install Pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from PIL import Image, ImageDraw, ImageFont
import pandas as pd

# cargar el DataFrame
df = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/EscuelaDeDataScienceEInteligenciaArtificial/Data e Inteligencia Artificial/Practicas/colegiosPrivadosColombia/COLEGIOS_PRIVADOS_Y_OFICIALES.csv')

# configurar la imagen
width, height = 1920, 1080
background_color = '#FFFFFF'
font_color = '#000000'
font_size = 30
font_type = '/usr/share/fonts/truetype/liberation/LiberationSans-Regular.ttf'
line_spacing = 50  # agregar 2 cm (50 pixeles) adicionales

espaciadoEnVertical=200

# abrir la fuente
font = ImageFont.truetype(font_type, font_size)

# iterar a través de cada fila del DataFrame
for index, row in df.iterrows():

    # crear la imagen
    image = Image.open('/content/drive/MyDrive/ColabNotebooks/EscuelaDeDataScienceEInteligenciaArtificial/Data e Inteligencia Artificial/Practicas/colegiosPrivadosColombia/portada.png')

    # agregar el texto
    draw = ImageDraw.Draw(image)
    text = row["nombreestablecimiento"]
    
    # calcular la posición del texto en la imagen
    text_width, text_height = draw.textsize(text, font=font)
    x = (width - text_width) // 2
    y = (height - text_height) // 2 +espaciadoEnVertical
    
    # escribir el texto en la imagen
    draw.text((x, y), text, font=font, fill=font_color)
    
    # agregar espacio adicional debajo del texto
    y += text_height + line_spacing

    # guardar la imagen
    image.save(f'/content/{row["nombreestablecimiento"]}.png')

# %% [markdown]
# # borrar todos los png

# %%
import os

# Obtener la lista de archivos en la ruta
files = os.listdir('/content/')

# Recorrer los archivos y borrar aquellos que tengan la extensión .png
for file in files:
    if file.endswith('.png'):
        os.remove(os.path.join('/content/', file))
