# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# !ls 'drive/MyDrive/ColabNotebooks/EscuelaDeDataScienceEInteligenciaArtificial/Data e Inteligencia Artificial/Practicas/colegiosPrivadosColombia/nuevaDataColegios'
# Out:
# colegios1.csv		    Colegios_Pereira_Privados.csv
# colegios2.csv		    COLEGIOS_PRIVADOS_EN_EL_DEPARTAMENTO_DEL_CESAR.csv
# colegios.csv		    Untitled0.ipynb
# Colegios_de_Yopal_2020.csv

# %%
df= pd.read_csv('drive/MyDrive/ColabNotebooks/EscuelaDeDataScienceEInteligenciaArtificial/Data e Inteligencia Artificial/Practicas/colegiosPrivadosColombia/nuevaDataColegios/Colegios_Pereira_Privados.csv')
df
# Out:
#        año secretaria  codigodepartamento nombredepartamento codigomunicipio  \
# 0    2,016    PEREIRA                  66          RISARALDA          66,001
# 1    2,016    PEREIRA                  66          RISARALDA          66,001
# 2    2,016    PEREIRA                  66          RISARALDA          66,001
# 3    2,016    PEREIRA                  66          RISARALDA          66,001
# 4    2,016    PEREIRA                  66          RISARALDA          66,001
# ..     ...        ...                 ...                ...             ...
# 247  2,016    PEREIRA                  66          RISARALDA          66,001
# 248  2,016    PEREIRA                  66          RISARALDA          66,001
# 249  2,016    PEREIRA                  66          RISARALDA          66,001
# 250  2,016    PEREIRA                  66          RISARALDA          66,001
# 251  2,016    PEREIRA                  66          RISARALDA          66,001
#
#     nombremunicipio codigoestablecimiento  \
# ...
