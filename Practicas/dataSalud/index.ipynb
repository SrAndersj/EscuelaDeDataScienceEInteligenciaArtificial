# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # para poder usar las hojas de calculo de google

# %%
url='https://docs.google.com/spreadsheets/d/e/2PACX-1vRJHkHEUBfwb9kHxfCBoewczEyo3SyFwoL4bddqa_wY27RNkB64qWA2p9FZoRVsqU8i4cSotKBfS081/pub?gid=0&single=true&output=csv'

df=pd.read_csv(url)
df
# Out:
#          fecha   hora finHora  peso kg  saltosDeLazo  dominadas  \
# 0   22/11/2022  17:00     NaN     84.8         300.0        2.0
# 1   23/11/2022  19:14   20:11     84.6         400.0        4.0
# 2    4/12/2022    NaN     NaN      NaN           NaN        NaN
# 3   12/12/2022   7:35     NaN      NaN         200.0        4.0
# 4   14/12/2022    NaN     NaN     84.8           NaN        NaN
# 5   15/12/2022    NaN     NaN      NaN           NaN        NaN
# 6   17/12/2022    NaN     NaN      NaN           NaN        NaN
# 7   18/12/2022    NaN     NaN      NaN           NaN        NaN
# 8   19/12/2022    NaN     NaN      NaN           NaN        NaN
# 9   20/12/2022    NaN     NaN      NaN           NaN        NaN
# 10  21/12/2022    NaN     NaN      NaN           NaN        NaN
# 11  23/12/2022    NaN     NaN      NaN           NaN        NaN
# 12  24/12/2022    NaN     NaN      NaN           NaN        NaN
# 13  27/12/2022    NaN     NaN      NaN           NaN        NaN
# ...

# %% [markdown]
# # Formato correcto de fechas
#
# ## mi colab
# https://colab.research.google.com/drive/1cg71LRyRy6XXZavmLahQn-kQCZgA1FJF
#
# ## w3school
#
# https://www.w3schools.com/python/pandas/pandas_cleaning_wrong_format.asp
#
#
# # **pandas.to_datetime**
#
# This function converts a scalar, array-like, Series or DataFrame/dict-like to a pandas datetime object.
#
# https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html

# %%
df.dtypes
# Out:
# fecha                   datetime64[ns]
# hora                            object
# finHora                         object
# peso kg                        float64
# saltosDeLazo                   float64
# dominadas                      float64
# sentadillasPesas               float64
# levantamientoDePesas           float64
# sentadillasSinPeso             float64
# desayuno                        object
# dHora                           object
# almuerzo                        object
# aHora                           object
# cena                            object
# cHora                           object
# mecato                          object
# mHora                           object
# mas                            float64
# masHora                         object
# losartan50mgMañana              object
# losartan noche                  object
# dtype: object

# %%
df['fecha']=pd.to_datetime(df['fecha'])

# %%
sns.jointplot(data=df,x='fecha',y='losartan50mgMañana')

# %%
pd.to_datetime(df['losartan50mgMañana'])
# Out:
# 0                    NaT
# 1                    NaT
# 2                    NaT
# 3                    NaT
# 4    2023-02-05 08:20:00
# 5                    NaT
# 6    2023-02-05 10:35:00
# 7                    NaT
# 8    2023-02-05 14:47:00
# 9    2023-02-05 09:23:00
# 10   2023-02-05 12:30:00
# 11   2023-02-05 08:37:00
# 12   2023-02-05 10:20:00
# 13   2023-02-05 10:38:00
# 14   2023-02-05 07:06:00
# 15   2023-02-05 07:56:00
# Name: losartan50mgMañana, dtype: datetime64[ns]

# %% [markdown]
# # Anexos de estudio y comprension

# %%
pd.to_datetime('2015-Jul-6')
# Out:
# Timestamp('2015-07-06 00:00:00')

# %%
pd.to_datetime('19/01/2023')
# Out:
# Timestamp('2023-01-19 00:00:00')

# %%
df['fecha'].astype(str)
# Out:
# 0     22/11/2022
# 1     23/11/2022
# 2      4/12/2022
# 3     12/12/2022
# 4     14/12/2022
# 5     15/12/2022
# 6     17/12/2022
# 7     18/12/2022
# 8     19/12/2022
# 9     20/12/2022
# 10    21/12/2022
# 11    23/12/2022
# 12    24/12/2022
# 13    27/12/2022
# 14    18/0172023
# 15    19/01/2023
# Name: fecha, dtype: object
