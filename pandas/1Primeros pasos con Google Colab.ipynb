# %%
a=34   #shif enter para ejecutar
b=a+5

2+5
# Out:
# 7

# %%
b
# Out:
# 39

# %%
'Hola Mundo'
# Out:
# 'Hola Mundo'

# %%
x='Hola'
y='Mundo'

x+' '+ y
# Out:
# 'Hola Mundo'

# %%
[1,2,3,4]
# Out:
# [1, 2, 3, 4]

# %%
[1,2,3,4,5]+[10]
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
lista=[1,2,3,4,5]

# %%
lista[0]
# Out:
# 1

# %%
lista[-1]
# Out:
# 5

# %%
import numpy as np # numpy para hacer operaciones

# %%
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.array([1,2,3,4,5])+10
# Out:
# array([11, 12, 13, 14, 15])

# %%
np.array([1,2,3,4,5]).shape  # shape longitud vector
# Out:
# (5,)

# %%
np.array([[1,2,3,4],[5,6,7,8]])  #una estructura matricial
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
np.array([[1,2,3,4],[5,6,7,8]]).shape
# Out:
# (2, 4)

# %%
np.array([[1,2,3,4],[5,6,7,8]])[0]
# Out:
# array([1, 2, 3, 4])

# %%
np.array([[1,2,3,4],[5,6,7,8]])[0][2]
# Out:
# 3
