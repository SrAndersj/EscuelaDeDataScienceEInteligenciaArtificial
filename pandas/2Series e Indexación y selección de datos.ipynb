# %%
import pandas as pd

# %%
pd.Series([10,6,7,8,4])
# Out:
# 0    10
# 1     6
# 2     7
# 3     8
# 4     4
# dtype: int64

# %%
sr=pd.Series([10,6,7,8,4])
sr
# Out:
# 0    10
# 1     6
# 2     7
# 3     8
# 4     4
# dtype: int64

# %%
sr.values
# Out:
# array([10,  6,  7,  8,  4])

# %%
sr.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
sr.shape
# Out:
# (5,)

# %%
sr[3]
# Out:
# 8

# %%
sr[[0,4,2]]
# Out:
# 0    10
# 4     4
# 2     7
# dtype: int64

# %%
sr=pd.Series([10,6,7,8,4],index=['a','b','c','d','e'])
sr
# Out:
# a    10
# b     6
# c     7
# d     8
# e     4
# dtype: int64

# %%
sr['c']
# Out:
# 7

# %%
sr[['c','a']]
# Out:
# c     7
# a    10
# dtype: int64

# %%
sr['b':'e']
# Out:
# b    6
# c    7
# d    8
# e    4
# dtype: int64

# %%
                 #diccionarios
           #llaves :dato
dict_data= {'CO':100 ,'MX':200 }      
dict_data
# Out:
# {'CO': 100, 'MX': 200}

# %%
dict_data.keys()
# Out:
# dict_keys(['CO', 'MX'])

# %%
dict_data['MX']
# Out:
# 200

# %%
pd.Series(dict_data) #convertir diccionario a pandas
# Out:
# CO    100
# MX    200
# dtype: int64

# %%
pd.Series(dict_data,index=['CO','MX','PE'])
# Out:
# CO    100.0
# MX    200.0
# PE      NaN
# dtype: float64

# %%
import numpy as np
np.nan  #nan es un objeto nulo que tambien cumple operaciones matematicas
# Out:
# nan

# %%
np.nan + 10
# Out:
# nan

# %%
sr=pd.Series(dict_data,index=['CO','MX','PE'])

# %%
sr.isnull()
# Out:
# CO    False
# MX    False
# PE     True
# dtype: bool

# %%
sr.notnull()
# Out:
# CO     True
# MX     True
# PE    False
# dtype: bool
