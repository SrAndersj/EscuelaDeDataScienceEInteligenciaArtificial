# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/My Drive/Colab Notebooks'
# !ls
# Out:
# /content/drive/My Drive/Colab Notebooks
# pandas

# %%
'Hola {}'.format('  blablalba alb')
# Out:
# 'Hola   blablalba alb'

# %%
# %cd '/content/drive/My Drive/Colab Notebooks/pandas'
# !ls
# Out:
# /content/drive/My Drive/Colab Notebooks/pandas
# '1Primeros pasos con Google Colab.ipynb'
# '2Series e Indexación y selección de datos.ipynb'
# '3De paneles de datos al DataFrame.ipynb'
# '4Indexado y manejo de archivos CSV.ipynb'
# '5Cómo usar Pandas y Python para conectar con tu base de datos SQL.ipynb'
# '6Ventajas y desventajas de los formatos de importar y guardado.ipynb'
# '7Formatos de lectura para cargar y guardar DataFrames.ipynb'
# '8Tipos de Variables que componen un data frame.ipynb'
#  db

# %%
# !mkdir /content/drive/My\ Drive/Colab\ Notebooks/pandas/db

# %%
dir_pandas='/content/drive/My Drive/Colab Notebooks/pandas/db/{}'.format('test.csv')
dir_pandas
# Out:
# '/content/drive/My Drive/Colab Notebooks/pandas/db/test.csv'

# %%
import pandas as pd
pd.__version__
import numpy as np

# %%
dict_data = {
    'edad' :     [ 10, 9, 13, 14, 12, 11, 12],
    'cm' : [ 115, 110, 130, 155, 125, 120, 125],
    'pais' :    [ 'co', 'mx', 'co', 'mx', 'mx', 'ch', 'ch'],
    'genero' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'Q1' : [ 5, 10, 8, np.nan, 7, 8, 3],
    'Q2' : [ 7, 9, 9, 8, 8, 8, 9.]
}
dict_data
# Out:
# {'Q1': [5, 10, 8, nan, 7, 8, 3],
#  'Q2': [7, 9, 9, 8, 8, 8, 9.0],
#  'cm': [115, 110, 130, 155, 125, 120, 125],
#  'edad': [10, 9, 13, 14, 12, 11, 12],
#  'genero': ['M', 'F', 'F', 'M', 'M', 'M', 'F'],
#  'pais': ['co', 'mx', 'co', 'mx', 'mx', 'ch', 'ch']}

# %%
df=pd.DataFrame(dict_data)
df
# Out:
#    edad   cm pais genero    Q1   Q2
# 0    10  115   co      M   5.0  7.0
# 1     9  110   mx      F  10.0  9.0
# 2    13  130   co      F   8.0  9.0
# 3    14  155   mx      M   NaN  8.0
# 4    12  125   mx      M   7.0  8.0
# 5    11  120   ch      M   8.0  8.0
# 6    12  125   ch      F   3.0  9.0

# %%
dir_pandas='/content/drive/My Drive/Colab Notebooks/pandas/db/{}'.format('test.csv')
dir_pandas
# Out:
# '/content/drive/My Drive/Colab Notebooks/pandas/db/test.csv'

# %%
df.to_csv(dir_pandas)

# %%
# !ls /content/drive/My\ Drive/Colab\ Notebooks/pandas/db
# Out:
# ls: cannot access '/content/drive/My Drive/Colab Notebooks/pandas/db': No such file or directory

# %%
df.to_csv(dir_pandas,index=False) #para no guardar el indice adicional

# %%
df_read=pd.read_csv('/content/drive/My Drive/Colab Notebooks/pandas/db/test.csv') #leer el archivo
df_read
# Out:
#    edad   cm pais genero    Q1   Q2
# 0    10  115   co      M   5.0  7.0
# 1     9  110   mx      F  10.0  9.0
# 2    13  130   co      F   8.0  9.0
# 3    14  155   mx      M   NaN  8.0
# 4    12  125   mx      M   7.0  8.0
# 5    11  120   ch      M   8.0  8.0
# 6    12  125   ch      F   3.0  9.0

# %% [markdown]
# el separador por defecto es la cmo , pero puedo definir otro separador con **sep**

# %%
df.to_csv(dir_pandas,sep='|',index=False)

# %% [markdown]
# como cambie el separdor que era la como entonces ahora el formato no reconoce y puso todo en una sola columna

# %%
df_read=pd.read_csv('/content/drive/My Drive/Colab Notebooks/pandas/db/test.csv') #leer el archivo
df_read
# Out:
#   edad|cm|pais|genero|Q1|Q2
# 0       10|115|co|M|5.0|7.0
# 1       9|110|mx|F|10.0|9.0
# 2       13|130|co|F|8.0|9.0
# 3          14|155|mx|M||8.0
# 4       12|125|mx|M|7.0|8.0
# 5       11|120|ch|M|8.0|8.0
# 6       12|125|ch|F|3.0|9.0

# %% [markdown]
# entonces yo le puedo decir al comando read cual es el separador

# %%
df_read=pd.read_csv('/content/drive/My Drive/Colab Notebooks/pandas/db/test.csv',sep='|') #leer el archivo indicando que el separador es |
df_read
# Out:
#    edad   cm pais genero    Q1   Q2
# 0    10  115   co      M   5.0  7.0
# 1     9  110   mx      F  10.0  9.0
# 2    13  130   co      F   8.0  9.0
# 3    14  155   mx      M   NaN  8.0
# 4    12  125   mx      M   7.0  8.0
# 5    11  120   ch      M   8.0  8.0
# 6    12  125   ch      F   3.0  9.0
